# %%
import json
import gzip
import pyodbc
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import text
import urllib
from urllib.request import urlopen
import traceback
import logging
from azure.storage.blob import BlobServiceClient
import time
import pandas as pd
import os

# %%
#Connect to database
def connect_to_azure():
   
    params = urllib.parse.quote_plus(r'Driver={ODBC Driver 17 for SQL Server};Server=#DB_URL#;Database=#DBNAME#;Uid=#DB_ID#;Pwd=#DB_KEY#;Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;')

    conn_str = 'mssql+pyodbc:///?odbc_connect={}'.format(params)
    engine_azure = create_engine(conn_str,echo=False)

    print('connection is ok')
    print(engine_azure.table_names())

    return engine_azure

# %%
engine_azure = connect_to_azure()
# Out:
# connection is ok
# ['all_pubs_linked', 'cord_publications', 'history', 'join_all_pubs_projs', 'join_oa_cord_doi', 'join_src_pubs_rels', 'join_trg_pubs_rels', 'oa_projects', 'oa_publications', 'oa_publications_three', 'oa_publications_three_copy', 'oa_publications_two', 'oa_pubs', 'oa_relationships', 'oa_relationships_copy', 'oa_relationships_copy_two', 'projects', 'projects_two']

# %% [markdown]
# ## Step 1. Get OpenAIRE publications that are in CORD19 and related to funded projects

# %%
df_final = pd.read_sql_table('join_all_pubs_projs', engine_azure)
df_final.head()
# Out:
#                                                 oaid  \
# 0  50|dedup_wf_001::9001ec12701e4ce5a66adbd25a377437
# 1  50|dedup_wf_001::7667e9e8013e45658fb3eae0be158d10
# 2  50|dedup_wf_001::e1d688bcaa8d8ff6760a1031106e130f
# 3  50|dedup_wf_001::7521e47071fa7dc2223634cf64d07fe3
# 4  50|dedup_wf_001::2c17496023455b7cad411efe9b5e1cdc
#
#                                             oa_title  \
# 0  GROMACS: High performance molecular simulation...
# 1  Imaging and spectroscopy of domains of the cel...
# 2  Subsumption Demodulation in First-Order Theore...
# 3  Induction of Cell-Cell Fusion by Ebola Virus G...
# 4  Interferon-induced transmembrane protein 3 blo...
#
#                           oa_doi   oa_pmid oa_arxiv oa_pub_date  cord_uid  \
# 0  10.1080/07391102.2020.1824816     empty    empty       empty  h62ii7ir
# 1             10.1039/d0an00696c     empty    empty       empty  fhr40sr3
# 2   10.1007/978-3-030-51074-9_17              empty       empty  pjnxv3zg
# 3   10.1371/journal.ppat.1005373  26730950    empty       empty  7ycgd0h7
# 4   10.1371/journal.ppat.1007532  30640957    empty       empty  15wxk8lt
#
#                                           cord_title  \
# 0  Repurposing of the approved small molecule dru...
# 1  Imaging and spectroscopy of domains of the cel...
# 2  Subsumption Demodulation in First-Order Theore...
# 3  Induction of Cell-Cell Fusion by Ebola Virus G...
# 4  Interferon-induced transmembrane protein 3 blo...
#
#                         cord_doi  cord_pmcid  ...  \
# 0  10.1080/07391102.2020.1824816  PMC7576931  ...
# 1             10.1039/d0an00696c        None  ...
# 2   10.1007/978-3-030-51074-9_17  PMC7324223  ...
# 3   10.1371/journal.ppat.1005373  PMC4711667  ...
# 4   10.1371/journal.ppat.1007532  PMC6347298  ...
#
#                                            proj_oaid        proj_code  \
# 0  40|corda_______::b21f6b1618151028fe7e3b4a2f2f894f           258980
# 1  40|corda__h2020::0875aa41d7225523933cecf91d83e5ab           665778
# 2  40|fwf_________::91dbeb8c3d808e456bbe8df2403038ee           W 1255
# 3  40|nih_________::01565c59f11b660d408e6da3ca911200  5R01AI053668-14
# 4  40|nih_________::01565c59f11b660d408e6da3ca911200  5R01AI053668-14
#
#                                           proj_title proj_startdate  \
# 0                  Million-core Molecular Simulation     2011-05-01
# 1  SUPPORTING MOBILITY IN THE ERA THROUGH AN INTE...     2015-09-01
# 2  Vollantrag zu Logical Methods in Computer Science     2014-03-01
# 3        Entry mechanisms used by a model retrovirus     2003-01-01
# 4        Entry mechanisms used by a model retrovirus     2003-01-01
#
#   proj_enddate currency     amount jurisdiction  \
# 0   2017-04-30    empty        0.0          EU;
# 1   2021-05-31      EUR  5841000.0          EU;
# 2   2022-02-28      EUR  6385130.0          AT;
# 3   2018-04-30    empty        0.0          US;
# 4   2018-04-30    empty        0.0          US;
#
#                          longname shortname
# 0            European Commission;       EC;
# 1            European Commission;       EC;
# 2    Austrian Science Fund (FWF);      FWF;
# 3  National Institutes of Health;      NIH;
# 4  National Institutes of Health;      NIH;
#
# [5 rows x 26 columns]

# %%
#Count projects per funder
proj_by_funders = df_final.groupby('longname')['proj_oaid'].nunique()
proj_by_funders.head()
# Out:
# longname
# Academy of Finland;                        46
# Australian Research Council (ARC);         44
# Austrian Science Fund (FWF);               34
# Canadian Institutes of Health Research;     1
# Croatian Science Foundation (CSF);          3
# Name: proj_oaid, dtype: int64

# %%
#Count CORD publications by funders
cov_pubs_by_funders = df_final.groupby("longname")['oaid'].count()
cov_pubs_by_funders.head()
# Out:
# longname
# Academy of Finland;                         85
# Australian Research Council (ARC);          50
# Austrian Science Fund (FWF);                53
# Canadian Institutes of Health Research;    788
# Croatian Science Foundation (CSF);           7
# Name: oaid, dtype: int64

# %%
#Calculate the funded amount
pd.options.display.float_format = '{:.2f}'.format
amount_by_funders = df_final.groupby("longname", sort = True)['amount'].sum()

# %%
#Aggregate data by funders
new_df = pd.DataFrame()
new_df['funder'] = proj_by_funders.index
new_df['COVID projects'] = proj_by_funders.values
new_df['COVID publications'] = cov_pubs_by_funders.values
new_df['project to pub ratio'] = new_df['COVID publications'] / new_df['COVID projects']
new_df['amount'] = amount_by_funders.values
new_df['amount to pub ratio'] = new_df['amount'] / new_df['COVID publications']
new_df
# Out:
#                                                funder  COVID projects  \
# 0                                 Academy of Finland;              46
# 1                  Australian Research Council (ARC);              44
# 2                        Austrian Science Fund (FWF);              34
# 3             Canadian Institutes of Health Research;               1
# 4                  Croatian Science Foundation (CSF);               3
# 5                                European Commission;             657
# 6       Fundação para a Ciência e a Tecnologia, I.P.;              48
# 7   Ministry of Education, Science and Technologic...              20
# 8   Ministry of Science, Education and Sports of t...               4
# 9   National Health and Medical Research Council (...             192
# 10                     National Institutes of Health;            2866
# 11  National Institutes of Health;National Institu...               6
# 12                       National Science Foundation;             329
# 13  Natural Sciences and Engineering Research Coun...               1
# 14  Netherlands Organisation for Scientific Resear...              47
# 15                               Research Council UK;             290
# 16                        Science Foundation Ireland;              16
# 17   Social Sciences and Humanities Research Council;               1
# 18                 Swiss National Science Foundation;             141
# 19   Türkiye Bilimsel ve Teknolojik Arastirma Kurumu;               3
# 20                                    Wellcome Trust;             227
#
#     COVID publications  project to pub ratio        amount  \
# 0                   85                  1.85   37316502.00
# 1                   50                  1.14          0.00
# 2                   53                  1.56   94655566.00
# 3                  788                788.00          0.00
# 4                    7                  2.33          0.00
# 5                 1814                  2.76 6050751891.80
# 6                   83                  1.73          0.00
# 7                   31                  1.55          0.00
# 8                    9                  2.25          0.00
# 9                  398                  2.07          0.00
# 10                6887                  2.40          0.00
# 11                  19                  3.17          0.00
# 12                 646                  1.96          0.00
# 13                 370                370.00          0.00
# 14                 166                  3.53          0.00
# 15                 679                  2.34          0.00
# 16                  38                  2.38          0.00
# 17                  23                 23.00          0.00
# 18                 258                  1.83          0.00
# 19                   5                  1.67          0.00
# 20                1488                  6.56 2135546023.00
#
#     amount to pub ratio
# 0             439017.67
# 1                  0.00
# 2            1785954.08
# 3                  0.00
# 4                  0.00
# 5            3335585.39
# 6                  0.00
# 7                  0.00
# 8                  0.00
# 9                  0.00
# 10                 0.00
# 11                 0.00
# 12                 0.00
# 13                 0.00
# 14                 0.00
# 15                 0.00
# 16                 0.00
# 17                 0.00
# 18                 0.00
# 19                 0.00
# 20           1435178.78

# %%
#Drop duplicates
df_final = df_final.drop_duplicates(subset=['oaid'])

# %% [markdown]
# ## Step 2. Use Semantic Scholar API to obtain citations/influential citations

# %%
#Given url, access semanticscholar api and get data
#returns dictionary of records
def get_sem_data(url):
    result = {}
    
    try:
        # store the response of URL
        response = urlopen(url)
        if response.status == 403:
            alert('Rate limited. Waiting to retry…')
            wait(response.retry-after)
            retry(url)
        
        # storing the JSON response 
        # from url in data
        data_json = json.loads(response.read())
        
        result['citations'] = str(data_json['numCitedBy'])
        result['influential citations'] = str(data_json['influentialCitationCount'])
        
        return result
    except Exception as e:
        if e.code == 404:
            pass
        else:
            logging.error(traceback.format_exc())

# %%
#Construct url and get semantic scholar data, saving it to the local folder
def get_semantic_scholar_citations():
    base_url = 'https://api.semanticscholar.org/v1/paper/'
    sem_list = []
    counter = 0
    start = 0
    for index, row in df_final.iterrows():
        if counter >= start:
            end_url = base_url + row['oa_doi']
            try:
                res_obj = get_sem_data(end_url)

                res_obj['oaid'] = row['oa_doi']

                sem_list.append(res_obj)
            except:
                print('problems with link')
            
            #We need to wait after each 100 requests due to API limitations
            if counter % 100 == 0:
                df_sem = pd.DataFrame(sem_list)
                filename = 'semantic_ + ' + str(start) + '_' + str(counter) + '.csv'
                df_sem.to_csv(filename,index=False)
                time.sleep(302)
            df_sem = pd.DataFrame(sem_list)
            filename = 'semantic_ + ' + str(start) + '_' + str(counter) + '.csv'
            df_sem.to_csv(filename,index=False)
        counter += 1
# Out:
# 2001
# https://api.semanticscholar.org/v1/paper/10.1007/s00249-020-01434-z
# 2002
# https://api.semanticscholar.org/v1/paper/10.3390/vaccines8020186
# 2003
# https://api.semanticscholar.org/v1/paper/10.1038/s41467-020-17543-4
# 2004
# https://api.semanticscholar.org/v1/paper/10.1016/j.chest.2020.05.530
# 2005
# https://api.semanticscholar.org/v1/paper/10.1111/pcmr.12776
# 2006
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-018-20002-2
# 2007
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-53288-8_6
# 2008
# https://api.semanticscholar.org/v1/paper/10.1038/gene.2014.56
# 2009
# https://api.semanticscholar.org/v1/paper/10.15172/pneu.2015.6/636
# 2010
# https://api.semanticscholar.org/v1/paper/10.1016/j.addr.2014.11.004
# 2011
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1002155
# 2012
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1001175
# 2013
# https://api.semanticscholar.org/v1/paper/10.1186/s13643-019-0991-y
# 2014
# https://api.semanticscholar.org/v1/paper/10.1186/s13643-017-0560-1
# 2015
# https://api.semanticscholar.org/v1/paper/10.1016/j.coviro.2014.06.002
# 2016
# https://api.semanticscholar.org/v1/paper/10.1038/s41467-020-14670-w
# 2017
# https://api.semanticscholar.org/v1/paper/10.1091/mbc.E10-04-0338
# 2018
# https://api.semanticscholar.org/v1/paper/10.1007/s10461-020-02856-8
# 2019
# https://api.semanticscholar.org/v1/paper/10.1093/ofid/ofx138
# 2020
# https://api.semanticscholar.org/v1/paper/10.1038/srep34862
# 2021
# https://api.semanticscholar.org/v1/paper/10.1016/j.chom.2016.08.005
# 2022
# https://api.semanticscholar.org/v1/paper/10.1086/652782
# 2023
# https://api.semanticscholar.org/v1/paper/10.1016/j.bpj.2016.10.014
# 2024
# https://api.semanticscholar.org/v1/paper/10.1128/CMR.00014-10
# 2025
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-019-46970-7
# 2026
# https://api.semanticscholar.org/v1/paper/10.1007/s00134-013-3186-3
# 2027
# https://api.semanticscholar.org/v1/paper/10.1017/S0950268814000946
# 2028
# https://api.semanticscholar.org/v1/paper/10.1038/s41366-018-0218-7
# 2029
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1001340
# 2030
# https://api.semanticscholar.org/v1/paper/10.1038/leu.2017.310
# 2031
# https://api.semanticscholar.org/v1/paper/10.1038/onc.2017.57
# 2032
# https://api.semanticscholar.org/v1/paper/10.1093/cvr/cvaa106
# 2033
# https://api.semanticscholar.org/v1/paper/10.1093/ve/vey002
# 2034
# https://api.semanticscholar.org/v1/paper/10.12688/wellcomeopenres.12429.2
# 2035
# https://api.semanticscholar.org/v1/paper/10.1038/sdata.2018.17
# 2036
# https://api.semanticscholar.org/v1/paper/10.1016/j.jcv.2013.02.019
# 2037
# https://api.semanticscholar.org/v1/paper/10.1038/s41597-019-0215-2
# 2038
# https://api.semanticscholar.org/v1/paper/10.1101/771394
# 2039
# https://api.semanticscholar.org/v1/paper/10.1007/s10393-019-01444-0
# 2040
# https://api.semanticscholar.org/v1/paper/10.3201/eid2212.160123
# 2041
# https://api.semanticscholar.org/v1/paper/10.1107/s205252062000846x
# 2042
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1002829
# 2043
# https://api.semanticscholar.org/v1/paper/10.1093/bioinformatics/btaa710
# 2044
# https://api.semanticscholar.org/v1/paper/10.1128/jvi.00711-20
# 2045
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.17.20069641
# 2046
# https://api.semanticscholar.org/v1/paper/10.1126/sciadv.aba0509
# 2047
# https://api.semanticscholar.org/v1/paper/10.3390/v11111062
# 2048
# https://api.semanticscholar.org/v1/paper/10.1080/15548627.2020.1782022
# 2049
# https://api.semanticscholar.org/v1/paper/10.1093/nar/gkm403
# 2050
# https://api.semanticscholar.org/v1/paper/10.1111/j.1753-4887.2009.00253.x
# 2051
# https://api.semanticscholar.org/v1/paper/10.1038/s41467-018-04409-z
# 2052
# https://api.semanticscholar.org/v1/paper/10.1101/787192
# 2053
# https://api.semanticscholar.org/v1/paper/10.1186/s40425-016-0128-y
# 2054
# https://api.semanticscholar.org/v1/paper/10.1016/j.vaccine.2014.08.058
# 2055
# https://api.semanticscholar.org/v1/paper/10.1128/mSphere.00152-18
# 2056
# https://api.semanticscholar.org/v1/paper/10.1186/s12864-019-6016-3
# 2057
# https://api.semanticscholar.org/v1/paper/10.1038/ncomms12127
# 2058
# https://api.semanticscholar.org/v1/paper/10.1038/ncb2788
# 2059
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2014.04.027
# 2060
# https://api.semanticscholar.org/v1/paper/10.5402/2012/738718
# 2061
# https://api.semanticscholar.org/v1/paper/10.1128/mBio.01107-13
# 2062
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0062833
# 2063
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0111466
# 2064
# https://api.semanticscholar.org/v1/paper/10.1053/j.tcam.2009.06.005
# 2065
# https://api.semanticscholar.org/v1/paper/10.1016/j.cytogfr.2011.06.001
# 2066
# https://api.semanticscholar.org/v1/paper/10.1136/svn-2019-000232
# 2067
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.24.058453
# 2068
# https://api.semanticscholar.org/v1/paper/10.1016/j.it.2012.12.002
# 2069
# https://api.semanticscholar.org/v1/paper/10.1021/acs.est.0c02895
# 2070
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0064137
# 2071
# https://api.semanticscholar.org/v1/paper/10.4049/jimmunol.1601340
# 2072
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.05.20091637
# 2073
# https://api.semanticscholar.org/v1/paper/10.3390/v11010035
# 2074
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2334-12-345
# 2075
# https://api.semanticscholar.org/v1/paper/10.3201/eid1307.060740
# 2076
# https://api.semanticscholar.org/v1/paper/10.1186/s12931-018-0750-y
# 2077
# https://api.semanticscholar.org/v1/paper/10.1080/20018525.2018.1487214
# 2078
# https://api.semanticscholar.org/v1/paper/10.1111/aji.13111
# 2079
# https://api.semanticscholar.org/v1/paper/10.1086/597122
# 2080
# https://api.semanticscholar.org/v1/paper/10.1186/s12866-015-0481-x
# 2081
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422X-8-262
# 2082
# https://api.semanticscholar.org/v1/paper/10.1016/j.cbpa.2018.05.003
# 2083
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1005501
# 2084
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1002198
# 2085
# https://api.semanticscholar.org/v1/paper/10.1002/hbe2.214
# 2086
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2164-11-251
# 2087
# https://api.semanticscholar.org/v1/paper/10.3390/v6072531
# 2088
# https://api.semanticscholar.org/v1/paper/10.15172/pneu.2015.6/645
# 2089
# https://api.semanticscholar.org/v1/paper/10.1016/j.tvjl.2011.12.009
# 2090
# https://api.semanticscholar.org/v1/paper/10.1128/genomea.01245-17
# 2091
# https://api.semanticscholar.org/v1/paper/10.1097/MD.0000000000001786
# 2092
# https://api.semanticscholar.org/v1/paper/10.1007/s00281-017-0646-9
# 2093
# https://api.semanticscholar.org/v1/paper/10.1016/j.smim.2016.04.006
# 2094
# https://api.semanticscholar.org/v1/paper/10.1111/j.1574-6976.2011.00306.x
# 2095
# https://api.semanticscholar.org/v1/paper/10.2807/1560-7917.ES.2020.25.12.2000293
# 2096
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.09.20096339
# 2097
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0001712
# 2098
# https://api.semanticscholar.org/v1/paper/10.1186/s12931-019-1201-0
# 2099
# https://api.semanticscholar.org/v1/paper/10.1038/ncomms10376
# 2100
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0011815
# going to sleep
# 2101
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.17.20069930
# 2102
# https://api.semanticscholar.org/v1/paper/10.1038/ncomms1466
# 2103
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.19.20069948
# 2104
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.05.20083436
# 2105
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0124646
# 2106
# https://api.semanticscholar.org/v1/paper/10.1038/srep12985
# 2107
# https://api.semanticscholar.org/v1/paper/10.1007/s10995-020-02983-7
# 2108
# https://api.semanticscholar.org/v1/paper/10.1111/j.1751-7915.2007.00012.x
# 2109
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0015243
# 2110
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2199-9-77
# 2111
# https://api.semanticscholar.org/v1/paper/10.1038/s41551-018-0275-1
# 2112
# https://api.semanticscholar.org/v1/paper/10.21203/rs.3.rs-49671/v1
# 2113
# https://api.semanticscholar.org/v1/paper/10.1016/j.ygeno.2020.09.028
# 2114
# https://api.semanticscholar.org/v1/paper/10.3390/v12101095
# 2115
# https://api.semanticscholar.org/v1/paper/10.1016/j.jmb.2020.07.009
# 2116
# https://api.semanticscholar.org/v1/paper/10.1101/2020.01.30.927889
# 2117
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0028507
# 2118
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0229467
# 2119
# https://api.semanticscholar.org/v1/paper/10.1186/1757-4749-5-22
# 2120
# https://api.semanticscholar.org/v1/paper/10.1016/j.chom.2016.01.011
# 2121
# https://api.semanticscholar.org/v1/paper/10.3390/biom7010029
# 2122
# https://api.semanticscholar.org/v1/paper/10.1152/ajpgi.00116.2016
# 2123
# https://api.semanticscholar.org/v1/paper/10.1038/s41536-020-0090-7
# 2124
# https://api.semanticscholar.org/v1/paper/10.1016/j.celrep.2017.10.005
# 2125
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0076892
# 2126
# https://api.semanticscholar.org/v1/paper/10.1186/s13054-014-0494-0
# 2127
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422X-6-86
# 2128
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.11.20061960
# 2129
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0063355
# 2130
# https://api.semanticscholar.org/v1/paper/10.1016/j.molcel.2013.12.025
# 2131
# https://api.semanticscholar.org/v1/paper/10.1038/nri2314
# 2132
# https://api.semanticscholar.org/v1/paper/10.1016/j.immuni.2009.04.013
# 2133
# https://api.semanticscholar.org/v1/paper/10.1096/fj.201902534r
# 2134
# https://api.semanticscholar.org/v1/paper/10.1038/s41541-020-0178-5
# 2135
# https://api.semanticscholar.org/v1/paper/10.7554/eLife.56649
# 2136
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2007.05.041
# 2137
# https://api.semanticscholar.org/v1/paper/10.3390/v3050493
# 2138
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0002406
# 2139
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1000287
# 2140
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0068558
# 2141
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2008.03.032
# 2142
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0018437
# 2143
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0045730
# 2144
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2008.11.034
# 2145
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0009986
# 2146
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1004063
# 2147
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0002181
# 2148
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0003863
# 2149
# https://api.semanticscholar.org/v1/paper/10.1007/s10393-010-0332-z
# 2150
# https://api.semanticscholar.org/v1/paper/10.1098/rstb.2012.0228
# 2151
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0067584
# 2152
# https://api.semanticscholar.org/v1/paper/10.1007/s10393-007-0149-6
# 2153
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-020-71294-2
# 2154
# https://api.semanticscholar.org/v1/paper/10.1017/s0950268814002635
# 2155
# https://api.semanticscholar.org/v1/paper/10.1086/511078
# 2156
# https://api.semanticscholar.org/v1/paper/10.3201/eid1902.120971
# 2157
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0238830
# 2158
# https://api.semanticscholar.org/v1/paper/10.3390/v3040379
# 2159
# https://api.semanticscholar.org/v1/paper/10.1186/s13578-015-0025-y
# 2160
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1006132
# 2161
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-017-07724-5
# 2162
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.20.051656
# 2163
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0067123
# 2164
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0023016
# 2165
# https://api.semanticscholar.org/v1/paper/10.3390/vaccines7010003
# 2166
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0186735
# 2167
# https://api.semanticscholar.org/v1/paper/10.1161/JAHA.119.012264
# 2168
# https://api.semanticscholar.org/v1/paper/10.1128/mbio.02063-14
# 2169
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.27.20081505
# 2170
# https://api.semanticscholar.org/v1/paper/10.3390/genes2040998
# 2171
# https://api.semanticscholar.org/v1/paper/10.4049/jimmunol.1000756
# 2172
# https://api.semanticscholar.org/v1/paper/10.1128/jvi.01363-19
# 2173
# https://api.semanticscholar.org/v1/paper/10.1021/acsenergylett.0c00839
# 2174
# https://api.semanticscholar.org/v1/paper/10.1101/2020.06.30.179754
# 2175
# https://api.semanticscholar.org/v1/paper/10.1016/j.coviro.2016.01.001
# 2176
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0008326
# 2177
# https://api.semanticscholar.org/v1/paper/10.1093/molbev/msu329
# 2178
# https://api.semanticscholar.org/v1/paper/10.12688/wellcomeopenres.14976.1
# 2179
# https://api.semanticscholar.org/v1/paper/10.1016/j.chom.2013.10.014
# 2180
# https://api.semanticscholar.org/v1/paper/10.1038/nrg3094
# 2181
# https://api.semanticscholar.org/v1/paper/10.1016/s1473-3099(19)30410-4
# 2182
# https://api.semanticscholar.org/v1/paper/10.3390/microorganisms8040501
# 2183
# https://api.semanticscholar.org/v1/paper/10.1111/nph.13008
# 2184
# https://api.semanticscholar.org/v1/paper/10.1007/s10875-019-00597-5
# 2185
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2105-11-210
# 2186
# https://api.semanticscholar.org/v1/paper/10.1016/j.jenvman.2020.111206
# 2187
# https://api.semanticscholar.org/v1/paper/10.3390/metabo9100200
# 2188
# https://api.semanticscholar.org/v1/paper/10.3390/ma13122796
# 2189
# https://api.semanticscholar.org/v1/paper/10.1080/20008686.2019.1685632
# 2190
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2334-11-105
# 2191
# https://api.semanticscholar.org/v1/paper/10.1093/ijnp/pyy085
# 2192
# https://api.semanticscholar.org/v1/paper/10.4103/0972-9941.72392
# 2193
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0000918
# 2194
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2005.01.035
# 2195
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1006593
# 2196
# https://api.semanticscholar.org/v1/paper/10.1101/320929
# 2197
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1002150
# 2198
# https://api.semanticscholar.org/v1/paper/10.1016/j.chom.2015.06.019
# 2199
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1002339
# 2200
# https://api.semanticscholar.org/v1/paper/10.1016/j.cvex.2004.09.002
# going to sleep
# 2201
# https://api.semanticscholar.org/v1/paper/10.1016/j.cvex.2004.09.004
# 2202
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2008.07.026
# 2203
# https://api.semanticscholar.org/v1/paper/10.1093/glycob/cwy053
# 2204
# https://api.semanticscholar.org/v1/paper/10.1007/s10928-020-09692-2
# 2205
# https://api.semanticscholar.org/v1/paper/10.1136/bmj.m793
# 2206
# https://api.semanticscholar.org/v1/paper/10.1007/s00044-010-9309-2
# 2207
# https://api.semanticscholar.org/v1/paper/10.1016/j.ejmech.2012.02.046
# 2208
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2334-12-311
# 2209
# https://api.semanticscholar.org/v1/paper/10.1016/j.chembiol.2008.07.008
# 2210
# https://api.semanticscholar.org/v1/paper/10.1186/1472-6807-5-5
# 2211
# https://api.semanticscholar.org/v1/paper/10.1007/978-1-4614-0980-9_3
# 2212
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-018-33873-2
# 2213
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422X-6-145
# 2214
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422x-5-28
# 2215
# https://api.semanticscholar.org/v1/paper/10.1016/j.virusres.2014.05.026
# 2216
# https://api.semanticscholar.org/v1/paper/10.1016/j.bbamem.2013.05.008
# 2217
# https://api.semanticscholar.org/v1/paper/10.1128/mbio.00105-15
# 2218
# https://api.semanticscholar.org/v1/paper/10.1128/mBio.00650-13
# 2219
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2015.06.016
# 2220
# https://api.semanticscholar.org/v1/paper/10.1111/cod.13685
# 2221
# https://api.semanticscholar.org/v1/paper/10.1016/j.virusres.2014.09.006
# 2222
# https://api.semanticscholar.org/v1/paper/10.1016/j.jviromet.2013.07.039
# 2223
# https://api.semanticscholar.org/v1/paper/10.1186/gm520
# 2224
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-019-38808-z
# 2225
# https://api.semanticscholar.org/v1/paper/10.1016/j.immuni.2007.07.004
# 2226
# https://api.semanticscholar.org/v1/paper/10.1186/s12942-020-00229-x
# 2227
# https://api.semanticscholar.org/v1/paper/10.1038/mt.2008.102
# 2228
# https://api.semanticscholar.org/v1/paper/10.1007/s11125-010-9133-y
# 2229
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0019181
# 2230
# https://api.semanticscholar.org/v1/paper/10.1007/s40473-016-0076-3
# 2231
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.08.20031666
# 2232
# https://api.semanticscholar.org/v1/paper/10.1016/j.jiph.2019.04.013
# 2233
# https://api.semanticscholar.org/v1/paper/10.1080/21505594.2020.1780088
# 2234
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.10.20059121
# 2235
# https://api.semanticscholar.org/v1/paper/10.1378/chest.107.6.1570
# 2236
# https://api.semanticscholar.org/v1/paper/10.1186/s40635-020-0295-5
# 2237
# https://api.semanticscholar.org/v1/paper/10.1093/aje/kww013
# 2238
# https://api.semanticscholar.org/v1/paper/10.1016/j.epidem.2016.04.002
# 2239
# https://api.semanticscholar.org/v1/paper/10.1371/currents.outbreaks.98d2f8f3382d84f390736cd5f5fe133c
# 2240
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0194527
# 2241
# https://api.semanticscholar.org/v1/paper/10.1098/rsos.180041
# 2242
# https://api.semanticscholar.org/v1/paper/10.1186/s12865-014-0055-y
# 2243
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.17.20104943
# 2244
# https://api.semanticscholar.org/v1/paper/10.1007/s00281-020-00790-4
# 2245
# https://api.semanticscholar.org/v1/paper/10.1038/srep34589
# 2246
# https://api.semanticscholar.org/v1/paper/10.3201/eid2305.161745
# 2247
# https://api.semanticscholar.org/v1/paper/10.1098/rsos.172341
# 2248
# https://api.semanticscholar.org/v1/paper/10.1136/bmjopen-2018-025145
# 2249
# https://api.semanticscholar.org/v1/paper/10.3390/v2122559
# 2250
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2164-8-274
# 2251
# https://api.semanticscholar.org/v1/paper/10.7554/elife.39494
# 2252
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.21.054015
# 2253
# https://api.semanticscholar.org/v1/paper/10.1007/bf02623451
# 2254
# https://api.semanticscholar.org/v1/paper/10.1038/s41579-018-0020-5
# 2255
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.02.017004
# 2256
# https://api.semanticscholar.org/v1/paper/10.1007/s12072-017-9826-x
# 2257
# https://api.semanticscholar.org/v1/paper/10.7554/elife.14228
# 2258
# https://api.semanticscholar.org/v1/paper/10.1007/s00134-011-2341-y
# 2259
# https://api.semanticscholar.org/v1/paper/10.1098/rsob.110036
# 2260
# https://api.semanticscholar.org/v1/paper/10.5469/neuroint.2015.10.1.34
# 2261
# https://api.semanticscholar.org/v1/paper/10.1016/j.isci.2020.101406
# 2262
# https://api.semanticscholar.org/v1/paper/10.1111/j.2044-8309.2011.02048.x
# 2263
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1003932
# 2264
# https://api.semanticscholar.org/v1/paper/10.1152/ajplung.00253.2019
# 2265
# https://api.semanticscholar.org/v1/paper/10.1016/j.buildenv.2017.11.025
# 2266
# https://api.semanticscholar.org/v1/paper/10.1016/j.buildenv.2019.106345
# 2267
# https://api.semanticscholar.org/v1/paper/10.1016/j.buildenv.2020.107206
# 2268
# https://api.semanticscholar.org/v1/paper/10.3389/fneur.2018.00996
# 2269
# https://api.semanticscholar.org/v1/paper/10.1212/WNL.0000000000004414
# 2270
# https://api.semanticscholar.org/v1/paper/10.1212/nxi.0000000000000375
# 2271
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-017-06882-w
# 2272
# https://api.semanticscholar.org/v1/paper/10.1177/1747493017706245
# 2273
# https://api.semanticscholar.org/v1/paper/10.1212/NXI.0000000000000214
# 2274
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0237029
# 2275
# https://api.semanticscholar.org/v1/paper/10.1038/nrd4663
# 2276
# https://api.semanticscholar.org/v1/paper/10.1016/j.dss.2009.04.016
# 2277
# https://api.semanticscholar.org/v1/paper/10.1016/j.vetimm.2019.109939
# 2278
# https://api.semanticscholar.org/v1/paper/10.1038/s41467-020-17367-2
# 2279
# https://api.semanticscholar.org/v1/paper/10.1107/s2052252520012725
# 2280
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.12.069831
# 2281
# https://api.semanticscholar.org/v1/paper/10.1021/acssensors.0c01180
# 2282
# https://api.semanticscholar.org/v1/paper/10.1007/s10640-020-00464-7
# 2283
# https://api.semanticscholar.org/v1/paper/10.1126/sciimmunol.aay5199
# 2284
# https://api.semanticscholar.org/v1/paper/10.1016/j.invent.2020.100348
# 2285
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1001039
# 2286
# https://api.semanticscholar.org/v1/paper/10.1111/irv.12687
# 2287
# https://api.semanticscholar.org/v1/paper/10.1128/mBio.00134-11
# 2288
# https://api.semanticscholar.org/v1/paper/10.1128/mBio.00056-13
# 2289
# https://api.semanticscholar.org/v1/paper/10.1038/s41522-019-0094-5
# 2290
# https://api.semanticscholar.org/v1/paper/10.1016/j.bbmt.2018.03.031
# 2291
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.12.037580
# 2292
# https://api.semanticscholar.org/v1/paper/10.1186/1742-2094-8-89
# 2293
# https://api.semanticscholar.org/v1/paper/10.1128/IAI.00651-18
# 2294
# https://api.semanticscholar.org/v1/paper/10.1186/s12883-015-0464-4
# 2295
# https://api.semanticscholar.org/v1/paper/10.1086/512615
# 2296
# https://api.semanticscholar.org/v1/paper/10.1186/s13567-016-0402-5
# 2297
# https://api.semanticscholar.org/v1/paper/10.1186/s13567-017-0472-z
# 2298
# https://api.semanticscholar.org/v1/paper/10.1093/tas/txy088
# 2299
# https://api.semanticscholar.org/v1/paper/10.1186/s12978-019-0824-4
# 2300
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.16.20067991
# going to sleep
# 2301
# https://api.semanticscholar.org/v1/paper/10.1038/s41540-019-0115-2
# 2302
# https://api.semanticscholar.org/v1/paper/10.3389/fcimb.2019.00459
# 2303
# https://api.semanticscholar.org/v1/paper/10.1016/j.jinf.2020.06.079
# 2304
# https://api.semanticscholar.org/v1/paper/10.1038/nri3265
# 2305
# https://api.semanticscholar.org/v1/paper/10.1016/j.clsr.2020.105431
# 2306
# https://api.semanticscholar.org/v1/paper/10.3390/jcm9061648
# 2307
# https://api.semanticscholar.org/v1/paper/10.1038/s41575-019-0140-z
# 2308
# https://api.semanticscholar.org/v1/paper/10.1007/s00220-020-03793-2
# 2309
# https://api.semanticscholar.org/v1/paper/10.3390/v10120714
# 2310
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.24.20078691
# 2311
# https://api.semanticscholar.org/v1/paper/10.1128/mBio.00272-18
# 2312
# https://api.semanticscholar.org/v1/paper/10.7554/elife.31919
# 2313
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1007390
# 2314
# https://api.semanticscholar.org/v1/paper/10.1093/aob/mcaa152
# 2315
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422x-10-278
# 2316
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-019-43232-4
# 2317
# https://api.semanticscholar.org/v1/paper/10.3390/v9060148
# 2318
# https://api.semanticscholar.org/v1/paper/10.1145/3415164
# 2319
# https://api.semanticscholar.org/v1/paper/10.1099/jgv.0.001047
# 2320
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0027106
# 2321
# https://api.semanticscholar.org/v1/paper/10.1016/j.tree.2015.07.005
# 2322
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1008643
# 2323
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pcbi.1002993
# 2324
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pcbi.1002015
# 2325
# https://api.semanticscholar.org/v1/paper/10.3201/eid2202.150967
# 2326
# https://api.semanticscholar.org/v1/paper/10.3390/v11111030
# 2327
# https://api.semanticscholar.org/v1/paper/10.3390/v10090477
# 2328
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0149150
# 2329
# https://api.semanticscholar.org/v1/paper/10.1103/PhysRevE.97.032308
# 2330
# https://api.semanticscholar.org/v1/paper/10.1084/jem.20131557
# 2331
# https://api.semanticscholar.org/v1/paper/10.1177/0025817220935752
# 2332
# https://api.semanticscholar.org/v1/paper/10.1128/jvi.01852-17
# 2333
# https://api.semanticscholar.org/v1/paper/10.1128/aac.02227-16
# 2334
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.08.20095687
# 2335
# https://api.semanticscholar.org/v1/paper/10.1186/s12874-020-00944-w
# 2336
# https://api.semanticscholar.org/v1/paper/10.1186/s12915-020-00829-w
# 2337
# https://api.semanticscholar.org/v1/paper/10.1111/ans.16255
# 2338
# https://api.semanticscholar.org/v1/paper/10.1136/bmjopen-2017-017533
# 2339
# https://api.semanticscholar.org/v1/paper/10.1038/s41436-018-0325-9
# 2340
# https://api.semanticscholar.org/v1/paper/10.1136/bmjopen-2019-033096
# 2341
# https://api.semanticscholar.org/v1/paper/10.1016/j.phytochem.2008.01.027
# 2342
# https://api.semanticscholar.org/v1/paper/10.1128/iai.00350-19
# 2343
# https://api.semanticscholar.org/v1/paper/10.3390/s19143175
# 2344
# https://api.semanticscholar.org/v1/paper/10.1038/cmi.2016.06
# 2345
# https://api.semanticscholar.org/v1/paper/10.1038/ncomms10680
# 2346
# https://api.semanticscholar.org/v1/paper/10.1016/j.chom.2020.04.009
# 2347
# https://api.semanticscholar.org/v1/paper/10.1016/j.it.2019.10.001
# 2348
# https://api.semanticscholar.org/v1/paper/10.1007/978-1-4939-6993-7_29
# 2349
# https://api.semanticscholar.org/v1/paper/10.1016/s2468-2667(20)30164-x
# 2350
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2458-3-5
# 2351
# https://api.semanticscholar.org/v1/paper/10.1016/j.anai.2017.12.023
# 2352
# https://api.semanticscholar.org/v1/paper/10.1016/j.micinf.2011.09.007
# 2353
# https://api.semanticscholar.org/v1/paper/10.1128/msystems.00741-20
# 2354
# https://api.semanticscholar.org/v1/paper/10.1002/oby.21106
# 2355
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.08.031203
# 2356
# https://api.semanticscholar.org/v1/paper/10.3390/v11010025
# 2357
# https://api.semanticscholar.org/v1/paper/10.1093/molbev/msy048
# 2358
# https://api.semanticscholar.org/v1/paper/10.1101/2020.03.24.992230
# 2359
# https://api.semanticscholar.org/v1/paper/10.1016/j.febslet.2006.04.004
# 2360
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1002661
# 2361
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1003512
# 2362
# https://api.semanticscholar.org/v1/paper/10.1038/nature10624
# 2363
# https://api.semanticscholar.org/v1/paper/10.1101/440628
# 2364
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2010.10.008
# 2365
# https://api.semanticscholar.org/v1/paper/10.1016/j.jmb.2013.11.024
# 2366
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0186034
# 2367
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0165326
# 2368
# https://api.semanticscholar.org/v1/paper/10.1002/hep4.1269
# 2369
# https://api.semanticscholar.org/v1/paper/10.3390/v12020131
# 2370
# https://api.semanticscholar.org/v1/paper/10.1038/nature23010
# 2371
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0074357
# 2372
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0101721
# 2373
# https://api.semanticscholar.org/v1/paper/10.1016/j.it.2016.10.008
# 2374
# https://api.semanticscholar.org/v1/paper/10.1038/nrmicro.2016.45
# 2375
# https://api.semanticscholar.org/v1/paper/10.1103/physreve.99.062301
# 2376
# https://api.semanticscholar.org/v1/paper/10.1103/physreve.97.052302
# 2377
# https://api.semanticscholar.org/v1/paper/10.1103/PhysRevE.100.062305
# 2378
# https://api.semanticscholar.org/v1/paper/10.1186/s13104-015-1695-6
# 2379
# https://api.semanticscholar.org/v1/paper/10.1378/chest.14-1481
# 2380
# https://api.semanticscholar.org/v1/paper/10.1186/1741-7015-11-252
# 2381
# https://api.semanticscholar.org/v1/paper/10.1103/PhysRevLett.124.217201
# 2382
# https://api.semanticscholar.org/v1/paper/10.1093/aje/kwt133
# 2383
# https://api.semanticscholar.org/v1/paper/10.1038/s41467-019-14229-4
# 2384
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0020086
# 2385
# https://api.semanticscholar.org/v1/paper/10.1007/s11356-016-7064-8
# 2386
# https://api.semanticscholar.org/v1/paper/10.1002/hbm.25122
# 2387
# https://api.semanticscholar.org/v1/paper/10.1016/j.vaccine.2019.04.056
# 2388
# https://api.semanticscholar.org/v1/paper/10.1038/ncomms9749
# 2389
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-018-31093-2
# 2390
# https://api.semanticscholar.org/v1/paper/10.1177/2396987317731004
# 2391
# https://api.semanticscholar.org/v1/paper/10.1161/strokeaha.116.015171
# 2392
# https://api.semanticscholar.org/v1/paper/10.1016/j.atmosenv.2020.117834
# 2393
# https://api.semanticscholar.org/v1/paper/10.1016/j.jpba.2013.09.025
# 2394
# https://api.semanticscholar.org/v1/paper/10.1098/rstb.2012.0196
# 2395
# https://api.semanticscholar.org/v1/paper/10.1007/s40265-020-01378-w
# 2396
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-019-42324-5
# 2397
# https://api.semanticscholar.org/v1/paper/10.1103/physreve.102.032308
# 2398
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0039284
# 2399
# https://api.semanticscholar.org/v1/paper/10.1016/j.ccm.2006.07.001
# 2400
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1000980
# going to sleep
# 2401
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-52200-1_11
# 2402
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.20.027144
# 2403
# https://api.semanticscholar.org/v1/paper/10.1021/acs.nanolett.0c02357
# 2404
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0005018
# 2405
# https://api.semanticscholar.org/v1/paper/10.1016/j.colsurfb.2020.111108
# 2406
# https://api.semanticscholar.org/v1/paper/10.1016/s2215-0366(20)30307-2
# 2407
# https://api.semanticscholar.org/v1/paper/10.1016/j.immuni.2017.01.010
# 2408
# https://api.semanticscholar.org/v1/paper/10.1084/jem.20151960
# 2409
# https://api.semanticscholar.org/v1/paper/10.1038/nri3694
# 2410
# https://api.semanticscholar.org/v1/paper/10.1016/j.imlet.2014.04.012
# 2411
# https://api.semanticscholar.org/v1/paper/10.1111/1467-8322.12572
# 2412
# https://api.semanticscholar.org/v1/paper/10.12688/wellcomeopenres.15813.1
# 2413
# https://api.semanticscholar.org/v1/paper/10.1016/j.virusres.2017.01.018
# 2414
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2011.01.013
# 2415
# https://api.semanticscholar.org/v1/paper/10.1016/b978-0-08-046884-6.01112-x
# 2416
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422X-8-405
# 2417
# https://api.semanticscholar.org/v1/paper/10.1016/j.eurpolymj.2017.02.014
# 2418
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pmed.1003018
# 2419
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0174980
# 2420
# https://api.semanticscholar.org/v1/paper/10.1007/s13365-012-0081-6
# 2421
# https://api.semanticscholar.org/v1/paper/10.1101/199059
# 2422
# https://api.semanticscholar.org/v1/paper/10.1534/g3.113.006254
# 2423
# https://api.semanticscholar.org/v1/paper/10.1007/s00705-015-2672-z
# 2424
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422X-6-164
# 2425
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.17.045161
# 2426
# https://api.semanticscholar.org/v1/paper/10.1016/j.jcv.2007.08.007
# 2427
# https://api.semanticscholar.org/v1/paper/10.1038/nbt.1564
# 2428
# https://api.semanticscholar.org/v1/paper/10.1136/neurintsurg-2012-010435
# 2429
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0204605
# 2430
# https://api.semanticscholar.org/v1/paper/10.1021/acs.estlett.6b00105
# 2431
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0200026
# 2432
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.17.047498
# 2433
# https://api.semanticscholar.org/v1/paper/10.1016/j.bbmt.2014.02.024
# 2434
# https://api.semanticscholar.org/v1/paper/10.3390/v5092298
# 2435
# https://api.semanticscholar.org/v1/paper/10.1177/1757913916650225
# 2436
# https://api.semanticscholar.org/v1/paper/10.3390/v5020732
# 2437
# https://api.semanticscholar.org/v1/paper/10.1016/b978-0-12-394385-9.00013-4
# 2438
# https://api.semanticscholar.org/v1/paper/10.1016/B978-0-12-394385-9.00009-2
# 2439
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.24.20077867
# 2440
# https://api.semanticscholar.org/v1/paper/10.1093/database/bap015
# 2441
# https://api.semanticscholar.org/v1/paper/10.12688/wellcomeopenres.12620.1
# 2442
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.01.072330
# 2443
# https://api.semanticscholar.org/v1/paper/10.1073/pnas.1718769115
# 2444
# https://api.semanticscholar.org/v1/paper/10.1111/obr.12941
# 2445
# https://api.semanticscholar.org/v1/paper/10.1186/s12879-015-1081-y
# 2446
# https://api.semanticscholar.org/v1/paper/10.1186/s12890-016-0353-7
# 2447
# https://api.semanticscholar.org/v1/paper/10.1002/ejhf.286
# 2448
# https://api.semanticscholar.org/v1/paper/10.1016/bs.aivir.2019.07.009
# 2449
# https://api.semanticscholar.org/v1/paper/10.1039/D0LC00364F
# 2450
# https://api.semanticscholar.org/v1/paper/10.1136/annrheumdis-2019-216016
# 2451
# https://api.semanticscholar.org/v1/paper/10.3390/s20123567
# 2452
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0027680
# 2453
# https://api.semanticscholar.org/v1/paper/10.1073/pnas.2010398117
# 2454
# https://api.semanticscholar.org/v1/paper/10.1093/jac/dkt314
# 2455
# https://api.semanticscholar.org/v1/paper/10.1002/aur.2329
# 2456
# https://api.semanticscholar.org/v1/paper/10.1039/d0sm00537a
# 2457
# https://api.semanticscholar.org/v1/paper/10.1101/292672
# 2458
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-018-34171-7
# 2459
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1003159
# 2460
# https://api.semanticscholar.org/v1/paper/10.1128/msphere.00379-16
# 2461
# https://api.semanticscholar.org/v1/paper/10.1038/nrmicro2614
# 2462
# https://api.semanticscholar.org/v1/paper/10.1007/s00134-004-2503-2
# 2463
# https://api.semanticscholar.org/v1/paper/10.1038/sj.gt.3303085
# 2464
# https://api.semanticscholar.org/v1/paper/10.1038/s41541-019-0109-5
# 2465
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1003389
# 2466
# https://api.semanticscholar.org/v1/paper/10.1038/nchem.2325
# 2467
# https://api.semanticscholar.org/v1/paper/10.1101/2020.02.07.939124
# 2468
# https://api.semanticscholar.org/v1/paper/10.2147/MDER.S46044
# 2469
# https://api.semanticscholar.org/v1/paper/10.4103/2152-7806.171239
# 2470
# https://api.semanticscholar.org/v1/paper/10.1111/j.1600-065x.2011.01062.x
# 2471
# https://api.semanticscholar.org/v1/paper/10.1038/nri3719
# 2472
# https://api.semanticscholar.org/v1/paper/10.1038/nm1240
# 2473
# https://api.semanticscholar.org/v1/paper/10.1038/s41522-019-0084-7
# 2474
# https://api.semanticscholar.org/v1/paper/10.3390/ijms20071677
# 2475
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0055271
# 2476
# https://api.semanticscholar.org/v1/paper/10.3390/v11020125
# 2477
# https://api.semanticscholar.org/v1/paper/10.1186/s12915-017-0447-6
# 2478
# https://api.semanticscholar.org/v1/paper/10.1192/bjp.2020.106
# 2479
# https://api.semanticscholar.org/v1/paper/10.1128/mSystems.00065-20
# 2480
# https://api.semanticscholar.org/v1/paper/10.15252/emmm.201607006
# 2481
# https://api.semanticscholar.org/v1/paper/10.1103/PhysRevE.84.061911
# 2482
# https://api.semanticscholar.org/v1/paper/10.1126/sciadv.aaz9386
# 2483
# https://api.semanticscholar.org/v1/paper/10.1101/2019.12.19.882175
# 2484
# https://api.semanticscholar.org/v1/paper/10.15252/emmm.202012063
# 2485
# https://api.semanticscholar.org/v1/paper/10.15252/embr.201949942
# 2486
# https://api.semanticscholar.org/v1/paper/10.1378/chest.115.3.901
# 2487
# https://api.semanticscholar.org/v1/paper/10.7554/eLife.31662
# 2488
# https://api.semanticscholar.org/v1/paper/10.3201/eid1905.121062
# 2489
# https://api.semanticscholar.org/v1/paper/10.1093/nar/gkn585
# 2490
# https://api.semanticscholar.org/v1/paper/10.1093/carcin/20.5.899
# 2491
# https://api.semanticscholar.org/v1/paper/10.1038/bmt.2013.100
# 2492
# https://api.semanticscholar.org/v1/paper/10.1186/s12967-020-02263-6
# 2493
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2008.01.018
# 2494
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2006.12.009
# 2495
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2012.10.010
# 2496
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1000570
# 2497
# https://api.semanticscholar.org/v1/paper/10.1016/j.coviro.2015.01.004
# 2498
# https://api.semanticscholar.org/v1/paper/10.7150/ntno.43808
# 2499
# https://api.semanticscholar.org/v1/paper/10.1189/jlb.0709518
# 2500
# https://api.semanticscholar.org/v1/paper/10.1101/2020.07.23.20160820
# going to sleep
# 2501
# https://api.semanticscholar.org/v1/paper/10.1016/j.jhin.2015.05.003
# 2502
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-020-62256-9
# 2503
# https://api.semanticscholar.org/v1/paper/10.1007/s11307-017-1055-0
# 2504
# https://api.semanticscholar.org/v1/paper/10.3390/v11070662
# 2505
# https://api.semanticscholar.org/v1/paper/10.1186/s12916-015-0526-x
# 2506
# https://api.semanticscholar.org/v1/paper/10.1098/rsif.2016.0279
# 2507
# https://api.semanticscholar.org/v1/paper/10.1093/infdis/jiw426
# 2508
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-017-10467-y
# 2509
# https://api.semanticscholar.org/v1/paper/10.1080/2162402X.2020.1774298
# 2510
# https://api.semanticscholar.org/v1/paper/10.1039/c7cs00822h
# 2511
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.29.20085738
# 2512
# https://api.semanticscholar.org/v1/paper/10.1101/2020.03.29.014761
# 2513
# https://api.semanticscholar.org/v1/paper/10.7554/elife.47117
# 2514
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2121-5-32
# 2515
# https://api.semanticscholar.org/v1/paper/10.1101/092619
# 2516
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.28.20083691
# 2517
# https://api.semanticscholar.org/v1/paper/10.1007/s00246-018-1994-5
# 2518
# https://api.semanticscholar.org/v1/paper/10.1016/j.vaccine.2012.03.035
# 2519
# https://api.semanticscholar.org/v1/paper/10.1007/s12014-010-9058-8
# 2520
# https://api.semanticscholar.org/v1/paper/10.1186/s12879-018-3425-x
# 2521
# https://api.semanticscholar.org/v1/paper/10.1086/655902
# 2522
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0013377
# 2523
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-020-73582-3
# 2524
# https://api.semanticscholar.org/v1/paper/10.3390/genes8010031
# 2525
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0001082
# 2526
# https://api.semanticscholar.org/v1/paper/10.1093/imammb/dqy009
# 2527
# https://api.semanticscholar.org/v1/paper/10.1177/2055116915615370
# 2528
# https://api.semanticscholar.org/v1/paper/10.1016/j.antiviral.2020.104874
# 2529
# https://api.semanticscholar.org/v1/paper/10.1101/635854
# 2530
# https://api.semanticscholar.org/v1/paper/10.1080/15476286.2015.1004955
# 2531
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-43520-2_3
# 2532
# https://api.semanticscholar.org/v1/paper/10.1007/s00251-019-01142-9
# 2533
# https://api.semanticscholar.org/v1/paper/10.3201/eid2104.141792
# 2534
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0095647
# 2535
# https://api.semanticscholar.org/v1/paper/10.1128/JVI.01105-13
# 2536
# https://api.semanticscholar.org/v1/paper/10.1586/14760584.2015.965690
# 2537
# https://api.semanticscholar.org/v1/paper/10.1016/j.antiviral.2013.06.009
# 2538
# https://api.semanticscholar.org/v1/paper/10.1136/bmjopen-2016-012296
# 2539
# https://api.semanticscholar.org/v1/paper/10.1021/np9003245
# 2540
# https://api.semanticscholar.org/v1/paper/10.1103/PhysRevE.98.022306
# 2541
# https://api.semanticscholar.org/v1/paper/10.1186/s12879-016-2003-3
# 2542
# https://api.semanticscholar.org/v1/paper/10.1103/PhysRevE.97.040301
# 2543
# https://api.semanticscholar.org/v1/paper/10.1103/PhysRevE.94.052316
# 2544
# https://api.semanticscholar.org/v1/paper/10.4161/mabs.29097
# 2545
# https://api.semanticscholar.org/v1/paper/10.1007/s10676-020-09547-x
# 2546
# https://api.semanticscholar.org/v1/paper/10.1084/jem.20161759
# 2547
# https://api.semanticscholar.org/v1/paper/10.1007/s11033-020-05831-7
# 2548
# https://api.semanticscholar.org/v1/paper/10.1186/s42155-020-00154-x
# 2549
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0139036
# 2550
# https://api.semanticscholar.org/v1/paper/10.1186/s40560-019-0412-2
# 2551
# https://api.semanticscholar.org/v1/paper/10.1016/S0014-5793(04)00302-3
# 2552
# https://api.semanticscholar.org/v1/paper/10.1016/j.jaci.2018.12.1004
# 2553
# https://api.semanticscholar.org/v1/paper/10.1007/s10544-008-9263-7
# 2554
# https://api.semanticscholar.org/v1/paper/10.1128/mBio.01340-14
# 2555
# https://api.semanticscholar.org/v1/paper/10.3390/vaccines5040045
# 2556
# https://api.semanticscholar.org/v1/paper/10.1177/0300060520956834
# 2557
# https://api.semanticscholar.org/v1/paper/10.1186/s12871-017-0395-2
# 2558
# https://api.semanticscholar.org/v1/paper/10.1186/s12951-020-0588-6
# 2559
# https://api.semanticscholar.org/v1/paper/10.1007/s12024-018-0043-2
# 2560
# https://api.semanticscholar.org/v1/paper/10.1016/j.biomaterials.2013.06.034
# 2561
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.09.20059964
# 2562
# https://api.semanticscholar.org/v1/paper/10.1016/j.dci.2018.11.022
# 2563
# https://api.semanticscholar.org/v1/paper/10.1016/j.ccm.2011.02.008
# 2564
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0058802
# 2565
# https://api.semanticscholar.org/v1/paper/10.1016/j.pt.2015.05.002
# 2566
# https://api.semanticscholar.org/v1/paper/10.1101/2019.12.20.884841
# 2567
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1007875
# 2568
# https://api.semanticscholar.org/v1/paper/10.1007/s00414-017-1638-y
# 2569
# https://api.semanticscholar.org/v1/paper/10.1101/719443
# 2570
# https://api.semanticscholar.org/v1/paper/10.1186/1472-6750-12-69
# 2571
# https://api.semanticscholar.org/v1/paper/10.12688/f1000research.18002.1
# 2572
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.19.20070805
# 2573
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.13.20059253
# 2574
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.08.20058214
# 2575
# https://api.semanticscholar.org/v1/paper/10.1007/s42770-020-00352-8
# 2576
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pbio.0060226
# 2577
# https://api.semanticscholar.org/v1/paper/10.1093/nar/gkr893
# 2578
# https://api.semanticscholar.org/v1/paper/10.1099/jgv.0.001098
# 2579
# https://api.semanticscholar.org/v1/paper/10.1161/strokeaha.115.011674
# 2580
# https://api.semanticscholar.org/v1/paper/10.1126/science.abc0473
# 2581
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.23.20076521
# 2582
# https://api.semanticscholar.org/v1/paper/10.1101/661579
# 2583
# https://api.semanticscholar.org/v1/paper/10.1093/ve/veaa007
# 2584
# https://api.semanticscholar.org/v1/paper/10.1128/JVI.00370-19
# 2585
# https://api.semanticscholar.org/v1/paper/10.1093/cid/ciy656
# 2586
# https://api.semanticscholar.org/v1/paper/10.1016/j.epidem.2015.12.002
# 2587
# https://api.semanticscholar.org/v1/paper/10.1016/j.arr.2010.05.005
# 2588
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.11.036855
# 2589
# https://api.semanticscholar.org/v1/paper/10.1101/2020.06.24.20139634
# 2590
# https://api.semanticscholar.org/v1/paper/10.1016/j.idm.2020.06.008
# 2591
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.12.20059972
# 2592
# https://api.semanticscholar.org/v1/paper/10.1177/2055116916630002
# 2593
# https://api.semanticscholar.org/v1/paper/10.1111/jphp.12929
# 2594
# https://api.semanticscholar.org/v1/paper/10.3389/fcimb.2019.00196
# 2595
# https://api.semanticscholar.org/v1/paper/10.3390/geriatrics5020024
# 2596
# https://api.semanticscholar.org/v1/paper/10.1002/agm2.12103
# 2597
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.24.20079012
# 2598
# https://api.semanticscholar.org/v1/paper/10.1101/222190
# 2599
# https://api.semanticscholar.org/v1/paper/10.1038/sj.mt.6300186
# 2600
# https://api.semanticscholar.org/v1/paper/10.1101/072652
# going to sleep
# 2601
# https://api.semanticscholar.org/v1/paper/10.1093/aje/kwm082
# 2602
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2012.05.018
# 2603
# https://api.semanticscholar.org/v1/paper/10.3390/v1030689
# 2604
# https://api.semanticscholar.org/v1/paper/10.1007/s10162-006-0051-x
# 2605
# https://api.semanticscholar.org/v1/paper/10.1016/j.virusres.2006.03.001
# 2606
# https://api.semanticscholar.org/v1/paper/10.1021/acs.chemrev.9b00472
# 2607
# https://api.semanticscholar.org/v1/paper/10.1002/oby.20433
# 2608
# https://api.semanticscholar.org/v1/paper/10.1016/j.neuroimage.2020.117358
# 2609
# https://api.semanticscholar.org/v1/paper/10.3390/v12010044
# 2610
# https://api.semanticscholar.org/v1/paper/10.1021/acsami.9b15032
# 2611
# https://api.semanticscholar.org/v1/paper/10.1007/s00216-020-02879-z
# 2612
# https://api.semanticscholar.org/v1/paper/10.1063/5.0021270
# 2613
# https://api.semanticscholar.org/v1/paper/10.1093/cid/ciz865
# 2614
# https://api.semanticscholar.org/v1/paper/10.2196/11456
# 2615
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.15.20103226
# 2616
# https://api.semanticscholar.org/v1/paper/10.1038/srep16119
# 2617
# https://api.semanticscholar.org/v1/paper/10.1016/j.cbi.2020.109125
# 2618
# https://api.semanticscholar.org/v1/paper/10.1186/1750-2187-8-7
# 2619
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0186984
# 2620
# https://api.semanticscholar.org/v1/paper/10.1007/s00281-017-0648-7
# 2621
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.15.20064980
# 2622
# https://api.semanticscholar.org/v1/paper/10.1084/jem.20160437
# 2623
# https://api.semanticscholar.org/v1/paper/10.1073/pnas.2008410117
# 2624
# https://api.semanticscholar.org/v1/paper/10.1016/j.coviro.2018.05.002
# 2625
# https://api.semanticscholar.org/v1/paper/10.1016/S0031-3955(05)70198-X
# 2626
# https://api.semanticscholar.org/v1/paper/10.1186/1476-072x-7-14
# 2627
# https://api.semanticscholar.org/v1/paper/10.1073/pnas.2010146117
# 2628
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-019-47713-4
# 2629
# https://api.semanticscholar.org/v1/paper/10.3201/eid2210.160097
# 2630
# https://api.semanticscholar.org/v1/paper/10.1038/ncomms11650
# 2631
# https://api.semanticscholar.org/v1/paper/10.1136/thoraxjnl-2016-209833
# 2632
# https://api.semanticscholar.org/v1/paper/10.1101/2020.03.22.20041145
# 2633
# https://api.semanticscholar.org/v1/paper/10.1016/j.idm.2020.02.003
# 2634
# https://api.semanticscholar.org/v1/paper/10.1101/2020.03.16.20037036
# 2635
# https://api.semanticscholar.org/v1/paper/10.1101/2020.03.08.20030643
# 2636
# https://api.semanticscholar.org/v1/paper/10.1186/s12916-019-1406-6
# 2637
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.14.20065524
# 2638
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.01.20049668
# 2639
# https://api.semanticscholar.org/v1/paper/10.1101/2020.02.20.20025866
# 2640
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0208197
# 2641
# https://api.semanticscholar.org/v1/paper/10.1007/s10393-017-1270-9
# 2642
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.03.20052688
# 2643
# https://api.semanticscholar.org/v1/paper/10.1038/nature17200
# 2644
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-018-30073-w
# 2645
# https://api.semanticscholar.org/v1/paper/10.4269/ajtmh.19-0502
# 2646
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422x-10-349
# 2647
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-020-64031-2
# 2648
# https://api.semanticscholar.org/v1/paper/10.2807/1560-7917.ES.2020.25.24.2001031
# 2649
# https://api.semanticscholar.org/v1/paper/10.1016/j.jaci.2020.04.043
# 2650
# https://api.semanticscholar.org/v1/paper/10.1007/s00204-020-02787-2
# 2651
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-019-51684-x
# 2652
# https://api.semanticscholar.org/v1/paper/10.1186/s12917-020-02299-2
# 2653
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-50433-5_50
# 2654
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0075346
# 2655
# https://api.semanticscholar.org/v1/paper/10.1007/s11065-020-09426-8
# 2656
# https://api.semanticscholar.org/v1/paper/10.1214/07-aoas105
# 2657
# https://api.semanticscholar.org/v1/paper/10.1016/j.plasmid.2014.05.004
# 2658
# https://api.semanticscholar.org/v1/paper/10.1007/s10096-018-03454-2
# 2659
# https://api.semanticscholar.org/v1/paper/10.1093/heapol/czs127
# 2660
# https://api.semanticscholar.org/v1/paper/10.1080/17441692.2012.725752
# 2661
# https://api.semanticscholar.org/v1/paper/10.3201/eid1606.091861
# 2662
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pgen.1000251
# 2663
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0033299
# 2664
# https://api.semanticscholar.org/v1/paper/10.1038/nri.2016.63
# 2665
# https://api.semanticscholar.org/v1/paper/10.3390/v7112915
# 2666
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1008087
# 2667
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2006.01.027
# 2668
# https://api.semanticscholar.org/v1/paper/10.3390/v11030260
# 2669
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.08.031435
# 2670
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.08.031526
# 2671
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0011304
# 2672
# https://api.semanticscholar.org/v1/paper/10.1186/cc13902
# 2673
# ...
# 5213
# https://api.semanticscholar.org/v1/paper/10.1038/s41565-018-0111-5
# 5214
# https://api.semanticscholar.org/v1/paper/10.1186/s13058-014-0506-7
# 5215
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0034508
# 5216
# https://api.semanticscholar.org/v1/paper/10.1016/j.mib.2011.07.014
# 5217
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pbio.1001571
# 5218
# https://api.semanticscholar.org/v1/paper/10.1016/j.scr.2016.04.017
# 5219
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.26.20080960
# 5220
# https://api.semanticscholar.org/v1/paper/10.1016/j.fsidi.2020.301011
# 5221
# https://api.semanticscholar.org/v1/paper/10.1111/obr.12848
# 5222
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.11.20098228
# 5223
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.27.20081836
# 5224
# https://api.semanticscholar.org/v1/paper/10.15252/emmm.202012465
# 5225
# https://api.semanticscholar.org/v1/paper/10.1016/j.coi.2018.10.007
# 5226
# https://api.semanticscholar.org/v1/paper/10.3390/vaccines6020018
# 5227
# https://api.semanticscholar.org/v1/paper/10.1038/s41591-020-0819-2
# 5228
# https://api.semanticscholar.org/v1/paper/10.1186/s40661-016-0023-8
# 5229
# https://api.semanticscholar.org/v1/paper/10.1093/nar/gks1254
# 5230
# https://api.semanticscholar.org/v1/paper/10.1016/j.ajic.2011.04.324
# 5231
# https://api.semanticscholar.org/v1/paper/10.2196/14731
# 5232
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.13.039321
# 5233
# https://api.semanticscholar.org/v1/paper/10.1093/pubmed/fdaa104
# 5234
# https://api.semanticscholar.org/v1/paper/10.1016/s2589-7500(20)30184-9
# 5235
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.04.20079301
# 5236
# https://api.semanticscholar.org/v1/paper/10.1098/rsif.2010.0216
# 5237
# https://api.semanticscholar.org/v1/paper/10.1098/rsif.2011.0309
# 5238
# https://api.semanticscholar.org/v1/paper/10.1177/0020731420946590
# 5239
# https://api.semanticscholar.org/v1/paper/10.1073/pnas.0908491107
# 5240
# https://api.semanticscholar.org/v1/paper/10.1136/bmj.b2651
# 5241
# https://api.semanticscholar.org/v1/paper/10.1099/vir.0.032094-0
# 5242
# https://api.semanticscholar.org/v1/paper/10.1099/vir.0.028381-0
# 5243
# https://api.semanticscholar.org/v1/paper/10.1186/s13643-019-0970-3
# 5244
# https://api.semanticscholar.org/v1/paper/10.1186/s11556-019-0213-6
# 5245
# https://api.semanticscholar.org/v1/paper/10.1111/irv.12668
# 5246
# https://api.semanticscholar.org/v1/paper/10.1093/nar/gks794
# 5247
# https://api.semanticscholar.org/v1/paper/10.1016/j.jaci.2016.12.963
# 5248
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.05.026336
# 5249
# https://api.semanticscholar.org/v1/paper/10.1007/s11214-020-00721-7
# 5250
# https://api.semanticscholar.org/v1/paper/10.1093/nar/gkt1220
# 5251
# https://api.semanticscholar.org/v1/paper/10.1093/nar/gku1256
# 5252
# https://api.semanticscholar.org/v1/paper/10.1016/j.antiviral.2016.12.023
# 5253
# https://api.semanticscholar.org/v1/paper/10.3390/v11070596
# 5254
# https://api.semanticscholar.org/v1/paper/10.1088/1361-6528/ab9327
# 5255
# https://api.semanticscholar.org/v1/paper/10.1016/j.sbi.2018.06.002
# 5256
# https://api.semanticscholar.org/v1/paper/10.1186/s12936-019-3093-3
# 5257
# https://api.semanticscholar.org/v1/paper/10.1016/j.chest.2018.04.019
# 5258
# https://api.semanticscholar.org/v1/paper/10.1186/1745-6215-12-94
# 5259
# https://api.semanticscholar.org/v1/paper/10.3390/ijms18071371
# 5260
# https://api.semanticscholar.org/v1/paper/10.1186/1742-2094-8-4
# 5261
# https://api.semanticscholar.org/v1/paper/10.1016/j.jneuroim.2014.02.012
# 5262
# https://api.semanticscholar.org/v1/paper/10.1128/jvi.01901-17
# 5263
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0069804
# 5264
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pmed.0040013
# 5265
# https://api.semanticscholar.org/v1/paper/10.1186/1741-7015-5-34
# 5266
# https://api.semanticscholar.org/v1/paper/10.1134/S0012496611040089
# 5267
# https://api.semanticscholar.org/v1/paper/10.1172/JCI64413
# 5268
# https://api.semanticscholar.org/v1/paper/10.1111/ijcp.13533
# 5269
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0031800
# 5270
# https://api.semanticscholar.org/v1/paper/10.1016/j.forpol.2020.102253
# 5271
# https://api.semanticscholar.org/v1/paper/10.1016/j.tifs.2020.09.021
# 5272
# https://api.semanticscholar.org/v1/paper/10.3389/fimmu.2019.02751
# 5273
# https://api.semanticscholar.org/v1/paper/10.1111/eva.12806
# 5274
# https://api.semanticscholar.org/v1/paper/10.1016/j.vaccine.2017.12.037
# 5275
# https://api.semanticscholar.org/v1/paper/10.1016/j.tim.2017.09.007
# 5276
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422x-7-17
# 5277
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422X-6-136
# 5278
# https://api.semanticscholar.org/v1/paper/10.1016/j.jpeds.2012.05.001
# 5279
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0000739
# 5280
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1003762
# 5281
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0026072
# 5282
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.08.20058073
# 5283
# https://api.semanticscholar.org/v1/paper/10.1007/s12250-020-00221-6
# 5284
# https://api.semanticscholar.org/v1/paper/10.1016/j.antiviral.2019.104667
# 5285
# https://api.semanticscholar.org/v1/paper/10.1016/j.celrep.2019.04.082
# 5286
# https://api.semanticscholar.org/v1/paper/10.1101/846071
# 5287
# https://api.semanticscholar.org/v1/paper/10.1007/s00109-008-0340-4
# 5288
# https://api.semanticscholar.org/v1/paper/10.1016/j.ceca.2018.08.003
# 5289
# https://api.semanticscholar.org/v1/paper/10.1203/PDR.0b013e3181e9f3a0
# 5290
# https://api.semanticscholar.org/v1/paper/10.3390/v10100547
# 5291
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-020-57545-2
# 5292
# https://api.semanticscholar.org/v1/paper/10.1021/acs.bioconjchem.0c00009
# 5293
# https://api.semanticscholar.org/v1/paper/10.1099/jgv.0.001110
# 5294
# https://api.semanticscholar.org/v1/paper/10.1128/jvi.00436-20
# 5295
# https://api.semanticscholar.org/v1/paper/10.1080/22221751.2020.1782271
# 5296
# https://api.semanticscholar.org/v1/paper/10.1364/OE.396734
# 5297
# https://api.semanticscholar.org/v1/paper/10.1016/j.cell.2020.06.034
# 5298
# https://api.semanticscholar.org/v1/paper/10.1038/nsmb.1772
# 5299
# https://api.semanticscholar.org/v1/paper/10.1186/s12905-018-0538-8
# 5300
# https://api.semanticscholar.org/v1/paper/10.3390/v5071684
# going to sleep
# 5301
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0108516
# 5302
# https://api.semanticscholar.org/v1/paper/10.3390/v5010279
# 5303
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0000020
# 5304
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pmed.0030003
# 5305
# https://api.semanticscholar.org/v1/paper/10.1016/j.chom.2010.05.007
# 5306
# https://api.semanticscholar.org/v1/paper/10.1038/s41467-020-18849-z
# 5307
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.26.20112649
# 5308
# https://api.semanticscholar.org/v1/paper/10.1007/s00277-020-04234-9
# 5309
# https://api.semanticscholar.org/v1/paper/10.1093/ije/dyq217
# 5310
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1002703
# 5311
# https://api.semanticscholar.org/v1/paper/10.3390/v6041759
# 5312
# https://api.semanticscholar.org/v1/paper/10.3201/eid1908.130119
# 5313
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0079665
# 5314
# https://api.semanticscholar.org/v1/paper/10.1186/s10020-020-00215-w
# 5315
# https://api.semanticscholar.org/v1/paper/10.1016/j.ajic.2018.11.021
# 5316
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-017-08490-0
# 5317
# https://api.semanticscholar.org/v1/paper/10.15698/mic2017.01.550
# 5318
# https://api.semanticscholar.org/v1/paper/10.1073/pnas.2001741117
# 5319
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.07.20056309
# 5320
# https://api.semanticscholar.org/v1/paper/10.7150/thno.47406
# 5321
# https://api.semanticscholar.org/v1/paper/10.1186/s12985-018-1020-9
# 5322
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0140701
# 5323
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1003774
# 5324
# https://api.semanticscholar.org/v1/paper/10.3389/fimmu.2016.00189
# 5325
# https://api.semanticscholar.org/v1/paper/10.1101/2020.02.10.942185
# 5326
# https://api.semanticscholar.org/v1/paper/10.1016/j.jmb.2009.09.040
# 5327
# https://api.semanticscholar.org/v1/paper/10.1210/en.2015-1556
# 5328
# https://api.semanticscholar.org/v1/paper/10.1126/science.aau4735
# 5329
# https://api.semanticscholar.org/v1/paper/10.1101/2020.03.25.008904
# 5330
# https://api.semanticscholar.org/v1/paper/10.1111/jon.12770
# 5331
# https://api.semanticscholar.org/v1/paper/10.1016/j.vaccine.2016.01.003
# 5332
# https://api.semanticscholar.org/v1/paper/10.1016/j.vaccine.2014.03.046
# 5333
# https://api.semanticscholar.org/v1/paper/10.1186/s13059-019-1923-9
# 5334
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.25.060954
# 5335
# https://api.semanticscholar.org/v1/paper/10.1007/s00436-019-06277-y
# 5336
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.28.067363
# 5337
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pbio.1001970
# 5338
# https://api.semanticscholar.org/v1/paper/10.1016/j.vaccine.2017.09.020
# 5339
# https://api.semanticscholar.org/v1/paper/10.1186/s12889-018-5628-x
# 5340
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.08.033001
# 5341
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.19.20069997
# 5342
# https://api.semanticscholar.org/v1/paper/10.1002/brb3.84
# 5343
# https://api.semanticscholar.org/v1/paper/10.1186/1743-422x-8-11
# 5344
# https://api.semanticscholar.org/v1/paper/10.3390/ijms21051676
# 5345
# https://api.semanticscholar.org/v1/paper/10.1186/1755-8794-2-49
# 5346
# https://api.semanticscholar.org/v1/paper/10.1111/irv.12684
# 5347
# https://api.semanticscholar.org/v1/paper/10.1186/s12992-018-0415-0
# 5348
# https://api.semanticscholar.org/v1/paper/10.1111/jth.15084
# 5349
# https://api.semanticscholar.org/v1/paper/10.1093/ve/vez033
# 5350
# https://api.semanticscholar.org/v1/paper/10.1080/08959420.2020.1765685
# 5351
# https://api.semanticscholar.org/v1/paper/10.1007/s00251-020-01174-6
# 5352
# https://api.semanticscholar.org/v1/paper/10.1111/dewb.12157
# 5353
# https://api.semanticscholar.org/v1/paper/10.1109/access.2020.3001298
# 5354
# https://api.semanticscholar.org/v1/paper/10.1186/s13100-015-0047-3
# 5355
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.14.20101378
# 5356
# https://api.semanticscholar.org/v1/paper/10.1111/1753-6405.13015
# 5357
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-49165-9_5
# 5358
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-49165-9_3
# 5359
# https://api.semanticscholar.org/v1/paper/10.1186/2051-5960-2-3
# 5360
# https://api.semanticscholar.org/v1/paper/10.1186/1471-2458-11-337
# 5361
# https://api.semanticscholar.org/v1/paper/10.1155/2012/569870
# 5362
# https://api.semanticscholar.org/v1/paper/10.3390/md12042114
# 5363
# https://api.semanticscholar.org/v1/paper/10.1101/2020.04.07.030734
# 5364
# https://api.semanticscholar.org/v1/paper/10.1186/s12917-018-1331-5
# 5365
# https://api.semanticscholar.org/v1/paper/10.3201/eid2412.180879
# 5366
# https://api.semanticscholar.org/v1/paper/10.1073/pnas.2004165117
# 5367
# https://api.semanticscholar.org/v1/paper/10.3390/ijerph17176169
# 5368
# https://api.semanticscholar.org/v1/paper/10.3390/vaccines7010011
# 5369
# https://api.semanticscholar.org/v1/paper/10.3390/v10030138
# 5370
# https://api.semanticscholar.org/v1/paper/10.1016/j.redox.2019.101198
# 5371
# https://api.semanticscholar.org/v1/paper/10.1093/cid/ciy495
# 5372
# https://api.semanticscholar.org/v1/paper/10.1063/5.0017585
# 5373
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.12.091090
# 5374
# https://api.semanticscholar.org/v1/paper/10.1586/14737159.2016.1112741
# 5375
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-48966-3_12
# 5376
# https://api.semanticscholar.org/v1/paper/10.1016/j.virol.2014.06.005
# 5377
# https://api.semanticscholar.org/v1/paper/10.1017/S0950268816002181
# 5378
# https://api.semanticscholar.org/v1/paper/10.1186/s12859-017-1665-1
# 5379
# https://api.semanticscholar.org/v1/paper/10.1093/gbe/evx251
# 5380
# https://api.semanticscholar.org/v1/paper/10.1007/s00408-018-0169-8
# 5381
# https://api.semanticscholar.org/v1/paper/10.1155/2015/506327
# 5382
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0017324
# 5383
# https://api.semanticscholar.org/v1/paper/10.1007/s41109-020-00317-8
# 5384
# https://api.semanticscholar.org/v1/paper/10.3233/NRE-172369
# 5385
# https://api.semanticscholar.org/v1/paper/10.1136/archdischild-2018-316773
# 5386
# https://api.semanticscholar.org/v1/paper/10.1128/JCM.03484-14
# 5387
# https://api.semanticscholar.org/v1/paper/10.3390/v8010016
# 5388
# https://api.semanticscholar.org/v1/paper/10.1038/nrmicro3312
# 5389
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-020-64060-x
# 5390
# https://api.semanticscholar.org/v1/paper/10.1007/s12253-020-00816-0
# 5391
# https://api.semanticscholar.org/v1/paper/10.1186/s41018-020-00072-6
# 5392
# https://api.semanticscholar.org/v1/paper/10.1016/j.celrep.2020.107968
# 5393
# https://api.semanticscholar.org/v1/paper/10.1016/j.jtbi.2008.07.018
# 5394
# https://api.semanticscholar.org/v1/paper/10.1016/j.jtbi.2008.09.035
# 5395
# https://api.semanticscholar.org/v1/paper/10.1016/j.jtbi.2008.11.017
# 5396
# https://api.semanticscholar.org/v1/paper/10.1186/s12987-020-00216-1
# 5397
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0023988
# 5398
# https://api.semanticscholar.org/v1/paper/10.1126/science.abe0322
# 5399
# https://api.semanticscholar.org/v1/paper/10.1038/nsmb0404-293
# 5400
# https://api.semanticscholar.org/v1/paper/10.1371/journal.ppat.1003595
# going to sleep
# 5401
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0156210
# 5402
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pone.0163829
# 5403
# https://api.semanticscholar.org/v1/paper/10.1038/s42003-018-0249-6
# 5404
# https://api.semanticscholar.org/v1/paper/10.1039/d0lc00304b
# 5405
# https://api.semanticscholar.org/v1/paper/10.1038/s41598-020-69364-6
# 5406
# https://api.semanticscholar.org/v1/paper/10.1016/j.molonc.2012.08.001
# 5407
# https://api.semanticscholar.org/v1/paper/10.1111/j.1600-065X.2010.01000.x
# 5408
# https://api.semanticscholar.org/v1/paper/10.1093/trstmh/traa072
# 5409
# https://api.semanticscholar.org/v1/paper/10.1016/j.ebiom.2018.05.032
# 5410
# https://api.semanticscholar.org/v1/paper/10.3390/v9080214
# 5411
# https://api.semanticscholar.org/v1/paper/10.1098/rspb.2017.2610
# 5412
# https://api.semanticscholar.org/v1/paper/10.1016/S1474-4422(15)00009-5
# 5413
# https://api.semanticscholar.org/v1/paper/10.1007/s13238-018-0535-6
# 5414
# https://api.semanticscholar.org/v1/paper/10.1007/978-3-030-45442-5_70
# 5415
# https://api.semanticscholar.org/v1/paper/10.3390/v8110304
# 5416
# https://api.semanticscholar.org/v1/paper/10.1101/2020.05.07.075093
# 5417
# https://api.semanticscholar.org/v1/paper/10.1099/jgv.0.000995
# 5418
# https://api.semanticscholar.org/v1/paper/10.1111/1475-5890.12232
# 5419
# https://api.semanticscholar.org/v1/paper/10.1111/1475-5890.12233
# 5420
# https://api.semanticscholar.org/v1/paper/10.1111/1475-5890.12229
# 5421
# https://api.semanticscholar.org/v1/paper/10.1371/journal.pntd.0008251
# 5422
# https://api.semanticscholar.org/v1/paper/10.1038/s41559-020-1242-2
# 5423
# https://api.semanticscholar.org/v1/paper/10.1007/s00439-016-1647-9
# 5424
# https://api.semanticscholar.org/v1/paper/10.1016/j.jcv.2019.09.003
# 5425
# https://api.semanticscholar.org/v1/paper/10.1088/1478-3975/aba6d0
# 5426
# https://api.semanticscholar.org/v1/paper/10.1136/bmjopen-2017-021194
# 5427
# https://api.semanticscholar.org/v1/paper/10.1186/s12961-019-0440-3
# 5428
# https://api.semanticscholar.org/v1/paper/10.1007/s10393-017-1264-7
# 5429
# https://api.semanticscholar.org/v1/paper/10.14336/ad.2020.0301
# 5430
# https://api.semanticscholar.org/v1/paper/10.1186/1532-429X-15-92
# 5431
# https://api.semanticscholar.org/v1/paper/10.3390/biom9110710
# 5432
# https://api.semanticscholar.org/v1/paper/10.3390/biom9050178
# 5433
# https://api.semanticscholar.org/v1/paper/10.3389/fimmu.2017.00258
# "for item in obj['pid']:\n   end_url = get_end_url(item['scheme'], item['value'])\n   #skip other schemes for now\n   if not end_url:\n       continue\n   full_url = base_url + end_url\n   print(full_url)\n   get_sem_data(full_url)\n"

# %%
def get_citation_table():
    filenames = os.listdir()
    semantic_files = [filename for filename in filenames if filename.startswith('semantic_')]
    
    dfs = [pd.read_csv(filename) for filename in semantic_files]
    final_df = pd.concat(dfs, ignore_index=True)
    
    df_sum_unique = final_df.drop_duplicates()

    return df_sum_unique

# %%
#First, files from semantic_data have to be unpacked into the same folder as the notebook
citation_table = get_citation_table()
citation_table.head()
# Out:
#    citations  influential citations                           oaid
# 0          6                      0  10.1080/07391102.2020.1824816
# 1          0                      0             10.1039/d0an00696c
# 2          4                      0   10.1007/978-3-030-51074-9_17
# 3         30                      2   10.1371/journal.ppat.1005373
# 4         34                      7   10.1371/journal.ppat.1007532

# %% [markdown]
# ## Step 3. Enrich final table with citations and influential citations

# %%
df = pd.merge(df_final,citation_table,left_on='oa_doi', right_on='oaid',how='left')

# %%
#Export to excel
df.to_excel('aLL_rows_table.xlsx')

# %% [markdown]
# ### Extract data for European Commission

# %%
ecdf = df.loc[df['shortname'] == 'EC;']
ecdf
# Out:
#                                                  oaid_x  \
# 0     50|dedup_wf_001::9001ec12701e4ce5a66adbd25a377437
# 1     50|dedup_wf_001::7667e9e8013e45658fb3eae0be158d10
# 35    50|dedup_wf_001::ba6d49008ea5b759d7842bab41ef100c
# 36    50|dedup_wf_001::545751d3799352206b93e1a4f2b34b4a
# 37    50|dedup_wf_001::4e9ab37f254220b9f1f1950283065f58
# ...                                                 ...
# 5410  50|dedup_wf_001::0aa743d2ff4a7f111c7381e39cd7579d
# 5411  50|dedup_wf_001::bf94c29c77af374502de61584b6f76ec
# 5423  50|dedup_wf_001::483a90ed604f97e529e467abba4ad91f
# 5424  50|dedup_wf_001::967b21879fc0fb82d8c255296472ecba
# 5425  50|dedup_wf_001::ce588a971b6639488ffff6e4674a252e
#
#                                                oa_title  \
# 0     GROMACS: High performance molecular simulation...
# 1     Imaging and spectroscopy of domains of the cel...
# 35    Treatment of COVID-19 Pneumonia: the Case for ...
# 36    Histo-blood group glycans in the context of pe...
# 37                 How to organize an online conference
# ...                                                 ...
# 5410  Characterization of a Novel RNA Virus Discover...
# 5411  Predicting the effects of parasite co-infectio...
# 5423  Harnessing publicly available genetic data to ...
# 5424  Comparison of phenotypic and genotypic diagnos...
# 5425  Testing of asymptomatic individuals for fast f...
#
#                              oa_doi   oa_pmid oa_arxiv oa_pub_date  cord_uid  \
# 0     10.1080/07391102.2020.1824816     empty    empty       empty  h62ii7ir
# 1                10.1039/d0an00696c     empty    empty       empty  fhr40sr3
# 35       10.1007/s12015-020-10004-x  32696426    empty       empty  9j9ni3wg
# 36     10.1016/j.bbagen.2015.12.026  26748235    empty       empty  5p9j5xj0
# 37        10.1038/s41578-020-0194-0     empty    empty       empty  hg4edj36
# ...                             ...       ...      ...         ...       ...
# 5410               10.3390/v9080214              empty       empty  1baso3q2
# 5411         10.1098/rspb.2017.2610  29540516    empty       empty  vcrbzzhu
# 5423      10.1007/s00439-016-1647-9  26946290    empty       empty  wrwp7ogi
# 5424      10.1016/j.jcv.2019.09.003  31521013    empty       empty  awr2tbj0
# 5425       10.1088/1478-3975/aba6d0     empty    empty       empty  iawtjm9j
#
#                                              cord_title  \
# 0     Repurposing of the approved small molecule dru...
# 1     Imaging and spectroscopy of domains of the cel...
# 35    Treatment of COVID-19 Pneumonia: the Case for ...
# 36    Histo-blood group glycans in the context of pe...
# 37                 How to organize an online conference
# ...                                                 ...
# 5410  Characterization of a Novel RNA Virus Discover...
# 5411  Predicting the effects of parasite co-infectio...
# 5423  Harnessing publicly available genetic data to ...
# 5424  Comparison of phenotypic and genotypic diagnos...
# 5425  Testing of asymptomatic individuals for fast f...
#
#                            cord_doi  cord_pmcid  ... proj_startdate  \
# 0     10.1080/07391102.2020.1824816  PMC7576931  ...     2011-05-01
# 1                10.1039/d0an00696c        None  ...     2015-09-01
# 35       10.1007/s12015-020-10004-x  PMC7372209  ...     2020-01-01
# 36     10.1016/j.bbagen.2015.12.026  PMC7117023  ...     2015-09-01
# 37        10.1038/s41578-020-0194-0  PMC7095294  ...     2017-04-01
# ...                             ...         ...  ...            ...
# 5410               10.3390/v9080214  PMC5580471  ...     2011-01-01
# 5411         10.1098/rspb.2017.2610  PMC5879626  ...     2015-05-22
# 5423      10.1007/s00439-016-1647-9  PMC4835528  ...     2013-10-01
# 5424      10.1016/j.jcv.2019.09.003  PMC7106360  ...     2013-09-01
# 5425       10.1088/1478-3975/aba6d0        None  ...     2019-05-01
#
#      proj_enddate currency      amount jurisdiction              longname  \
# 0      2017-04-30    empty        0.00          EU;  European Commission;
# 1      2021-05-31      EUR  5841000.00          EU;  European Commission;
# 35     2024-12-31      EUR  6844620.00          EU;  European Commission;
# 36     2019-08-31      EUR  3293890.00          EU;  European Commission;
# 37     2022-09-30      EUR  1999890.00          EU;  European Commission;
# ...           ...      ...         ...          ...                   ...
# 5410   2015-12-31    empty        0.00          EU;  European Commission;
# 5411   2016-08-21      EUR   112673.00          EU;  European Commission;
# 5423   2017-03-31    empty        0.00          EU;  European Commission;
# 5424   2017-02-28    empty        0.00          EU;  European Commission;
# 5425   2025-04-30      EUR 13937500.00          EU;  European Commission;
#
#      shortname citations influential citations                         oaid_y
# 0          EC;      6.00                  0.00  10.1080/07391102.2020.1824816
# 1          EC;      0.00                  0.00             10.1039/d0an00696c
# 35         EC;      2.00                  0.00     10.1007/s12015-020-10004-x
# 36         EC;     18.00                  1.00   10.1016/j.bbagen.2015.12.026
# 37         EC;     20.00                  0.00      10.1038/s41578-020-0194-0
# ...        ...       ...                   ...                            ...
# 5410       EC;      6.00                  0.00               10.3390/v9080214
# 5411       EC;     14.00                  0.00         10.1098/rspb.2017.2610
# 5423       EC;     10.00                  2.00      10.1007/s00439-016-1647-9
# 5424       EC;      1.00                  0.00      10.1016/j.jcv.2019.09.003
# 5425       EC;      3.00                  0.00       10.1088/1478-3975/aba6d0
#
# [894 rows x 29 columns]

# %% [markdown]
# ### Find top projects by citations

# %%
ecdf.groupby(['proj_title'])['citations'].agg('sum').reset_index().sort_values(by=['citations'], ascending=False).to_excel('top_proj.xlsx')

# %% [markdown]
# ### Find top projects by influential citations

# %%
ecdf.groupby(['proj_title'])['influential citations'].agg('sum').reset_index().sort_values(by=['influential citations'], ascending=False).to_excel('top_proj_inf.xlsx')

# %% [markdown]
# ### Find top projects by publication count

# %%
ecdf.groupby(['proj_title'])['citations'].agg('count').reset_index().sort_values(by=['citations'], ascending=False).to_excel('top_proj_pub_count.xlsx')

# %% [markdown]
# ## Step 4. Aggregate the final table by funders

# %%
df.loc[df['citations'] > 0]
# Out:
#                                                  oaid_x  \
# 101   50|dedup_wf_001::3c8cd854535bbf53a45363e6fae9afd7
# 102   50|dedup_wf_001::35cb19f220f7d3974726f3ce2a52df5e
# 103   50|dedup_wf_001::c7adc248fd2b293c1b5de76ddd918896
# 104   50|dedup_wf_001::c0dc5cb4e9c24974eea633931eb9d797
# 105   50|dedup_wf_001::1568062058ffd299a162b5d4ac08510a
# ...                                                 ...
# 5429  50|dedup_wf_001::b0fdbfba077427c97120a881845d4780
# 5430  50|dedup_wf_001::829344a03f04c2a1a9445658316d15f8
# 5431  50|dedup_wf_001::de458fac816db7268d5ec90fca9e590b
# 5432  50|dedup_wf_001::1cd6834b6cdd391dc04b4d2137e322bb
# 5433  50|dedup_wf_001::beb1f2ddd043c7181afc97c5ed7c58e7
#
#                                                oa_title  \
# 101   Efficient Sensing of Infected Cells in Absence...
# 102   COVID-19 pandemic changes the food consumption...
# 103   Social network-based distancing strategies to ...
# 104   Demographic science aids in understanding the ...
# 105   Forecasting spatial, socioeconomic and demogra...
# ...                                                 ...
# 5429  Mesenchymal Stem Cell Infusion Shows Promise f...
# 5430  Myocardial T1 mapping and extracellular volume...
# 5431  Zika and Flavivirus Shell Disorder: Virulence ...
# 5432       HIV Vaccine Mystery and Viral Shell Disorder
# 5433  Type I and III interferon in the gut: tight ba...
#
#                             oa_doi   oa_pmid oa_arxiv oa_pub_date  cord_uid  \
# 101   10.1371/journal.ppat.1003412  23785283    empty       empty  2mceonc1
# 102     10.1016/j.tifs.2020.08.017     empty    empty       empty  l5r1hl8x
# 103      10.1038/s41562-020-0898-6  17283616    empty       empty  qpzg8lam
# 104    10.1101/2020.03.15.20036293  32400861    empty       empty  gv8wlo06
# 105     10.1186/s12916-020-01646-2  32594909    empty       empty  5nnlyavp
# ...                            ...       ...      ...         ...       ...
# 5429         10.14336/ad.2020.0301  32257554    empty       empty  v73bsrwg
# 5430       10.1186/1532-429X-15-92  24124732    empty       empty  ogv0yga9
# 5431           10.3390/biom9110710  31698857    empty       empty  nmt221tu
# 5432           10.3390/biom9050178  31072073    empty       empty  q28h5zi8
# 5433      10.3389/fimmu.2017.00258  28352268    empty       empty  ma7tsm68
#
#                                              cord_title  \
# 101   Efficient Sensing of Infected Cells in Absence...
# 102   COVID-19 pandemic changes the food consumption...
# 103   Social network-based distancing strategies to ...
# 104   Demographic science aids in understanding the ...
# 105   Forecasting spatial, socioeconomic and demogra...
# ...                                                 ...
# 5429  Mesenchymal Stem Cell Infusion Shows Promise f...
# 5430  Myocardial T1 mapping and extracellular volume...
# 5431  Zika and Flavivirus Shell Disorder: Virulence ...
# 5432       HIV Vaccine Mystery and Viral Shell Disorder
# 5433  Type I and III Interferon in the Gut: Tight Ba...
#
#                           cord_doi  cord_pmcid  ... proj_startdate  \
# 101   10.1371/journal.ppat.1003412  PMC3681750  ...     2010-04-01
# 102     10.1016/j.tifs.2020.08.017  PMC7462788  ...     2019-10-01
# 103      10.1038/s41562-020-0898-6        None  ...     2019-11-01
# 104    10.1101/2020.03.15.20036293        None  ...     2019-11-01
# 105     10.1186/s12916-020-01646-2  PMC7321716  ...     2019-11-01
# ...                            ...         ...  ...            ...
# 5429         10.14336/ad.2020.0301  PMC7069463  ...     2018-06-15
# 5430       10.1186/1532-429x-15-92        None  ...          empty
# 5431           10.3390/biom9110710  PMC6920988  ...     2010-08-01
# 5432           10.3390/biom9050178  PMC6572542  ...     2010-08-01
# 5433      10.3389/fimmu.2017.00258  PMC5348535  ...     2016-05-01
#
#      proj_enddate currency      amount jurisdiction  \
# 101    2014-03-31    empty        0.00          EU;
# 102    2023-09-30      EUR 10189600.00          EU;
# 103    2024-10-31      EUR  2499810.00          EU;
# 104    2024-10-31      EUR  2499810.00          EU;
# 105    2024-10-31      EUR  2499810.00          EU;
# ...           ...      ...         ...          ...
# 5429   2023-05-31    empty        0.00          US;
# 5430        empty    empty        0.00          US;
# 5431   2021-07-31    empty        0.00          US;
# 5432   2021-07-31    empty        0.00          US;
# 5433   2019-10-31    empty        0.00          GB;
#
#                             longname shortname citations  \
# 101             European Commission;       EC;     41.00
# 102             European Commission;       EC;     11.00
# 103             European Commission;       EC;    174.00
# 104             European Commission;       EC;     13.00
# 105             European Commission;       EC;     13.00
# ...                              ...       ...       ...
# 5429  National Institutes of Health;      NIH;     61.00
# 5430  National Institutes of Health;      NIH;    735.00
# 5431    National Science Foundation;      NSF;     13.00
# 5432    National Science Foundation;      NSF;     19.00
# 5433            Research Council UK;     RCUK;     26.00
#
#      influential citations                        oaid_y
# 101                   2.00  10.1371/journal.ppat.1003412
# 102                   0.00    10.1016/j.tifs.2020.08.017
# 103                  10.00     10.1038/s41562-020-0898-6
# 104                   0.00   10.1101/2020.03.15.20036293
# 105                   0.00    10.1186/s12916-020-01646-2
# ...                    ...                           ...
# 5429                  5.00         10.14336/ad.2020.0301
# 5430                 26.00       10.1186/1532-429X-15-92
# 5431                  0.00           10.3390/biom9110710
# 5432                  2.00           10.3390/biom9050178
# 5433                  1.00      10.3389/fimmu.2017.00258
#
# [5059 rows x 29 columns]

# %% [markdown]
# ### Count projects per funder

# %%
proj_by_funders = df.groupby('longname')['proj_oaid'].nunique()
proj_by_funders.head()
# Out:
# longname
# Academy of Finland;                        31
# Australian Research Council (ARC);         38
# Austrian Science Fund (FWF);               26
# Canadian Institutes of Health Research;     1
# Croatian Science Foundation (CSF);          3
# Name: proj_oaid, dtype: int64

# %% [markdown]
# ### Count CORD publications by funders

# %%
cov_pubs_by_funders = df.groupby("longname")['oaid_x'].count()
cov_pubs_by_funders.head()
# Out:
# longname
# Academy of Finland;                         39
# Australian Research Council (ARC);          42
# Austrian Science Fund (FWF);                27
# Canadian Institutes of Health Research;    472
# Croatian Science Foundation (CSF);           4
# Name: oaid_x, dtype: int64

# %%
pd.options.display.float_format = '{:.2f}'.format
amount_by_funders = df.groupby("longname", sort = True)['amount'].sum()

# %% [markdown]
# ### Count citations and influential citations by funders

# %%
citations_by_funders = df.groupby("longname", sort = True)['citations'].sum()
citations_by_funders
# Out:
# longname
# Academy of Finland;                                                                      952.00
# Australian Research Council (ARC);                                                       502.00
# Austrian Science Fund (FWF);                                                            1144.00
# Canadian Institutes of Health Research;                                                24166.00
# Croatian Science Foundation (CSF);                                                        67.00
# European Commission;                                                                   39592.00
# Fundação para a Ciência e a Tecnologia, I.P.;                                           2176.00
# Ministry of Education, Science and Technological Development of Republic of Serbia;      244.00
# Ministry of Science, Education and Sports of the Republic of Croatia (MSES);             108.00
# National Health and Medical Research Council (NHMRC);                                   4103.00
# National Institutes of Health;                                                        121666.00
# National Institutes of Health;National Institutes of Health;                              82.00
# National Science Foundation;                                                           11744.00
# Natural Sciences and Engineering Research Council of Canada;                            9277.00
# Netherlands Organisation for Scientific Research (NWO);                                 5091.00
# Research Council UK;                                                                    6858.00
# Science Foundation Ireland;                                                             1103.00
# Social Sciences and Humanities Research Council;                                         508.00
# Swiss National Science Foundation;                                                      5206.00
# Türkiye Bilimsel ve Teknolojik Arastirma Kurumu;                                          23.00
# Wellcome Trust;                                                                        31902.00
# Name: citations, dtype: float64

# %%
inf_citations_by_funders = df.groupby("longname", sort = True)['influential citations'].sum()
inf_citations_by_funders
# Out:
# longname
# Academy of Finland;                                                                     45.00
# Australian Research Council (ARC);                                                      22.00
# Austrian Science Fund (FWF);                                                            48.00
# Canadian Institutes of Health Research;                                                997.00
# Croatian Science Foundation (CSF);                                                       3.00
# European Commission;                                                                  1996.00
# Fundação para a Ciência e a Tecnologia, I.P.;                                           89.00
# Ministry of Education, Science and Technological Development of Republic of Serbia;     12.00
# Ministry of Science, Education and Sports of the Republic of Croatia (MSES);             2.00
# National Health and Medical Research Council (NHMRC);                                  164.00
# National Institutes of Health;                                                        6084.00
# National Institutes of Health;National Institutes of Health;                             3.00
# National Science Foundation;                                                           552.00
# Natural Sciences and Engineering Research Council of Canada;                           498.00
# Netherlands Organisation for Scientific Research (NWO);                                336.00
# Research Council UK;                                                                   355.00
# Science Foundation Ireland;                                                             66.00
# Social Sciences and Humanities Research Council;                                        24.00
# Swiss National Science Foundation;                                                     272.00
# Türkiye Bilimsel ve Teknolojik Arastirma Kurumu;                                         0.00
# Wellcome Trust;                                                                       1666.00
# Name: influential citations, dtype: float64

# %% [markdown]
# ### Construct the final dataframe for export to Excel

# %%
new_df = pd.DataFrame()
new_df['funder'] = proj_by_funders.index
new_df['COVID projects'] = proj_by_funders.values
new_df['COVID publications'] = cov_pubs_by_funders.values
new_df['project to pub ratio'] = new_df['COVID publications'] / new_df['COVID projects']
new_df['funding'] = amount_by_funders.values
new_df['funding to pub ratio'] = new_df['funding'] / new_df['COVID publications']
new_df['citations'] = citations_by_funders.values
new_df['influential citations'] = inf_citations_by_funders.values
new_df['citations to pub ratio'] = new_df['citations'] / new_df['COVID publications']
new_df['influential citations to pub ratio'] = new_df['influential citations'] / new_df['COVID publications']
new_df['funding to citations ratio'] = new_df['funding'] / new_df['citations']
new_df['funding to influential citations ratio'] = new_df['funding'] / new_df['influential citations']
new_df
# Out:
#                                                funder  COVID projects  \
# 0                                 Academy of Finland;              31
# 1                  Australian Research Council (ARC);              38
# 2                        Austrian Science Fund (FWF);              26
# 3             Canadian Institutes of Health Research;               1
# 4                  Croatian Science Foundation (CSF);               3
# 5                                European Commission;             543
# 6       Fundação para a Ciência e a Tecnologia, I.P.;              28
# 7   Ministry of Education, Science and Technologic...              12
# 8   Ministry of Science, Education and Sports of t...               3
# 9   National Health and Medical Research Council (...             120
# 10                     National Institutes of Health;            1595
# 11  National Institutes of Health;National Institu...               6
# 12                       National Science Foundation;             206
# 13  Natural Sciences and Engineering Research Coun...               1
# 14  Netherlands Organisation for Scientific Resear...              35
# 15                               Research Council UK;             187
# 16                        Science Foundation Ireland;              12
# 17   Social Sciences and Humanities Research Council;               1
# 18                 Swiss National Science Foundation;             100
# 19   Türkiye Bilimsel ve Teknolojik Arastirma Kurumu;               2
# 20                                    Wellcome Trust;             132
#
#     COVID publications  project to pub ratio       funding  \
# 0                   39                  1.26   17766222.00
# 1                   42                  1.11          0.00
# 2                   27                  1.04   39467117.00
# 3                  472                472.00          0.00
# 4                    4                  1.33          0.00
# 5                  894                  1.65 2947962098.40
# 6                   30                  1.07          0.00
# 7                   13                  1.08          0.00
# 8                    4                  1.33          0.00
# 9                  143                  1.19          0.00
# 10                2165                  1.36          0.00
# 11                   9                  1.50          0.00
# 12                 237                  1.15          0.00
# 13                 256                256.00          0.00
# 14                  63                  1.80          0.00
# 15                 236                  1.26          0.00
# 16                  16                  1.33          0.00
# 17                  20                 20.00          0.00
# 18                 119                  1.19          0.00
# 19                   2                  1.00          0.00
# 20                 643                  4.87  549753757.00
#
#     funding to pub ratio  citations  influential citations  \
# 0              455544.15     735.00                  45.00
# 1                   0.00     475.00                  22.00
# 2             1461745.07    1140.00                  48.00
# 3                   0.00   24166.00                 997.00
# 4                   0.00      67.00                   3.00
# 5             3297496.75   39019.00                1996.00
# 6                   0.00    2176.00                  89.00
# 7                   0.00     244.00                  12.00
# 8                   0.00     108.00                   2.00
# 9                   0.00    4048.00                 164.00
# 10                  0.00  118849.00                6084.00
# 11                  0.00      59.00                   3.00
# 12                  0.00   11655.00                 552.00
# 13                  0.00    9277.00                 498.00
# 14                  0.00    5091.00                 336.00
# 15                  0.00    6786.00                 355.00
# 16                  0.00    1103.00                  66.00
# 17                  0.00     508.00                  24.00
# 18                  0.00    5189.00                 272.00
# 19                  0.00      23.00                   0.00
# 20             854982.51   31902.00                1666.00
#
#     citations to pub ratio  influential citations to pub ratio  \
# 0                    18.85                                1.15
# 1                    11.31                                0.52
# 2                    42.22                                1.78
# 3                    51.20                                2.11
# 4                    16.75                                0.75
# 5                    43.65                                2.23
# 6                    72.53                                2.97
# 7                    18.77                                0.92
# 8                    27.00                                0.50
# 9                    28.31                                1.15
# 10                   54.90                                2.81
# 11                    6.56                                0.33
# 12                   49.18                                2.33
# 13                   36.24                                1.95
# 14                   80.81                                5.33
# 15                   28.75                                1.50
# 16                   68.94                                4.12
# 17                   25.40                                1.20
# 18                   43.61                                2.29
# 19                   11.50                                0.00
# 20                   49.61                                2.59
#
#     funding to citations ratio  funding to influential citations ratio
# 0                     24171.73                               394804.93
# 1                         0.00                                    0.00
# 2                     34620.28                               822231.60
# 3                         0.00                                    0.00
# 4                         0.00                                    0.00
# 5                     75551.96                              1476934.92
# 6                         0.00                                    0.00
# 7                         0.00                                    0.00
# 8                         0.00                                    0.00
# 9                         0.00                                    0.00
# 10                        0.00                                    0.00
# 11                        0.00                                    0.00
# 12                        0.00                                    0.00
# 13                        0.00                                    0.00
# 14                        0.00                                    0.00
# 15                        0.00                                    0.00
# 16                        0.00                                    0.00
# 17                        0.00                                    0.00
# 18                        0.00                                    0.00
# 19                        0.00                                     nan
# 20                    17232.58                               329984.25

# %% [markdown]
# ### Export to Excel

# %%
new_df.to_excel('final_table.xlsx')
